# %% [markdown]
# <a href="https://colab.research.google.com/github/saipklvs/rlLearningExamplesBook/blob/master/TFGNN_Football.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install tensorflow_gnn

# %%
#!pip install basemap

# %% [markdown]
# # TF-GNN Football Example
# ##### The dataset is a network of universities and the football games they played against each other. Each school node has a conference which we will be trying to predict. I also create a feature indicating if a game is an in-conference game for making edge predictions as well.
# ### Imports

# %%
import pandas as pd
import numpy as np
import networkx as nx
import tensorflow as tf
import tensorflow_gnn as tfgnn
import urllib.request
import matplotlib.pyplot as plt
import io
import zipfile
import sys

from difflib import SequenceMatcher
from mpl_toolkits.basemap import Basemap
from sklearn.model_selection import train_test_split
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

# %% [markdown]
# ### Data Download

# %%
url = "http://www-personal.umich.edu/~mejn/netdata/football.zip"
sock = urllib.request.urlopen(url)  # open URL
s = io.BytesIO(sock.read())  # read into BytesIO "file"
sock.close()

zf = zipfile.ZipFile(s)  # zipfile object
txt = zf.read("football.txt").decode()  # read info file
gml = zf.read("football.gml").decode()  # read gml data
# throw away bogus first line with # from mejn files
gml = gml.split("\n")[1:]
G = nx.parse_gml(gml)  # parse gml data
print(txt)
# Out:
# The file football.gml contains the network of American football games
# between Division IA colleges during regular season Fall 2000, as compiled
# by M. Girvan and M. Newman.  The nodes have values that indicate to which
# conferences they belong.  The values are as follows:
#
#   0 = Atlantic Coast
#   1 = Big East
#   2 = Big Ten
#   3 = Big Twelve
#   4 = Conference USA
#   5 = Independents
#   6 = Mid-American
#   7 = Mountain West
#   8 = Pacific Ten
#   9 = Southeastern
#  10 = Sun Belt
#  11 = Western Athletic
#
# If you make use of these data, please cite M. Girvan and M. E. J. Newman,
# Community structure in social and biological networks,
# Proc. Natl. Acad. Sci. USA 99, 7821-7826 (2002).
#
# Correction: Two edges were erroneously duplicated in this data set, and
# have been removed (21 SEP 2014)

# %% [markdown]
# ### Visualization

# %%
cmap = {0:'#bd2309', 1:'#bbb12d',2:'#1480fa',3:'#14fa2f',4:'#faf214',
        5:'#2edfea',6:'#ea2ec4',7:'#ea2e40',8:'#577a4d',9:'#2e46c0',
        10:'#f59422',11:'#8086d9'}

colors = [cmap[G.nodes[n]['value']] for n in G.nodes()]
pos = nx.spring_layout(G, seed=1987)

nx.draw_networkx_edges(G, pos, alpha=0.2)
nx.draw_networkx_nodes(G, pos, nodelist=G.nodes(),
                       node_color=colors, node_size=100)

# %% [markdown]
# # Data
# ### Extract Node & Edge Dataframes

# %%
node_df = pd.DataFrame.from_dict(dict(G.nodes(data=True)), orient='index')
node_df.index.name = 'school'
node_df.columns = ['conference']

edge_df = nx.to_pandas_edgelist(G)

# %% [markdown]
# ### Add Node Features
# ##### Add lat-long coordinates, and previous year rank, wins, and conference wins

# %%
node_data = {'AirForce': {'Latitude': 38.996093, 'Longitude': -104.857222, 'Rank': 83, 'Wins': 6, 'Conf_wins': 2},
             'Akron': {'Latitude': 41.075346, 'Longitude': -81.512184, 'Rank': 66, 'Wins': 7, 'Conf_wins': 5},
             'Alabama': {'Latitude': 33.215775, 'Longitude': -87.538261, 'Rank': 101, 'Wins': 10, 'Conf_wins': 7},
             'AlabamaBirmingham': {'Latitude': 33.501569, 'Longitude': -86.805677, 'Rank': 52, 'Wins': 5, 'Conf_wins': 4},
             'Arizona': {'Latitude': 32.248814, 'Longitude': -110.987419, 'Rank': 90, 'Wins': 6, 'Conf_wins': 3}, 
             'ArizonaState': {'Latitude': 33.424564, 'Longitude': -111.928001, 'Rank': 88, 'Wins': 6, 'Conf_wins': 5},
             'Arkansas': {'Latitude': 36.068213, 'Longitude': -94.1748, 'Rank': 103, 'Wins': 8, 'Conf_wins': 4},
             'ArkansasState': {'Latitude': 35.842722, 'Longitude': -90.674584, 'Rank': 45, 'Wins': 4, 'Conf_wins': 2},
             'Army': {'Latitude': 39.343777, 'Longitude': -94.915748, 'Rank': 54, 'Wins': 3, 'Conf_wins': 1},
             'Auburn': {'Latitude': 32.593357, 'Longitude': -85.495163, 'Rank': 105, 'Wins': 5, 'Conf_wins': 2},
             'BallState': {'Latitude': 40.207953, 'Longitude': -85.413456, 'Rank': 76, 'Wins': 0, 'Conf_wins': 0},
             'Baylor': {'Latitude': 31.549612, 'Longitude': -97.114885, 'Rank': 21, 'Wins': 1, 'Conf_wins': 0},
             'BoiseState': {'Latitude': 43.6036, 'Longitude': -116.20871, 'Rank': 41, 'Wins': 10, 'Conf_wins': 5},
             'BostonCollege': {'Latitude': 42.350876, 'Longitude': -71.106918, 'Rank': 24, 'Wins': 8, 'Conf_wins': 4},
             'BowlingGreenState': {'Latitude': 41.379698, 'Longitude': -83.630737, 'Rank': 68, 'Wins': 5, 'Conf_wins': 3},
             'BrighamYoung': {'Latitude': 40.251475, 'Longitude': -111.649241, 'Rank': 78, 'Wins': 8, 'Conf_wins': 5},
             'Buffalo': {'Latitude': 43.000291, 'Longitude': -78.789165, 'Rank': 70, 'Wins': 0, 'Conf_wins': 0},
             'California': {'Latitude': 37.871853, 'Longitude': -122.258423, 'Rank': 92, 'Wins': 4, 'Conf_wins': 3},
             'CentralFlorida': {'Latitude': 28.602378, 'Longitude': -81.20025, 'Rank': 61, 'Wins': 4, 'Conf_wins': 0},
             'CentralMichigan': {'Latitude': 43.590972, 'Longitude': -84.776213, 'Rank': 75, 'Wins': 4, 'Conf_wins': 3},
             'Cincinnati': {'Latitude': 39.132827, 'Longitude': -84.514935, 'Rank': 56, 'Wins': 3, 'Conf_wins': 0},
             'Clemson': {'Latitude': 34.673227, 'Longitude': -82.836745, 'Rank': 4, 'Wins': 6, 'Conf_wins': 5},
             'Colorado': {'Latitude': 40.006638, 'Longitude': -105.267476, 'Rank': 12, 'Wins': 7, 'Conf_wins': 5},
             'ColoradoState': {'Latitude': 40.573181, 'Longitude': -105.086386, 'Rank': 79, 'Wins': 8, 'Conf_wins': 5},
             'Connecticut': {'Latitude': 41.807281, 'Longitude': -72.254646, 'Rank': 115, 'Wins': 4, 'Conf_wins': 3},
             'Duke': {'Latitude': 36.001465, 'Longitude': -78.939133, 'Rank': 7, 'Wins': 3, 'Conf_wins': 3},
             'EastCarolina': {'Latitude': 35.60684, 'Longitude': -77.366564, 'Rank': 49, 'Wins': 9, 'Conf_wins': 4},
             'EasternMichigan': {'Latitude': 42.250631, 'Longitude': -83.624152, 'Rank': 74, 'Wins': 4, 'Conf_wins': 4},
             'Florida': {'Latitude': 29.643946, 'Longitude': -82.355659, 'Rank': 95, 'Wins': 9, 'Conf_wins': 7},
             'FloridaState': {'Latitude': 30.441805, 'Longitude': -84.298521, 'Rank': 1, 'Wins': 12, 'Conf_wins': 8},
             'FresnoState': {'Latitude': 36.811754, 'Longitude': -119.748511, 'Rank': 109, 'Wins': 8, 'Conf_wins': 5},
             'Georgia': {'Latitude': 33.948006, 'Longitude': -83.377319, 'Rank': 97, 'Wins': 8, 'Conf_wins': 5},
             'GeorgiaTech': {'Latitude': 33.775529, 'Longitude': -84.396311, 'Rank': 2, 'Wins': 8, 'Conf_wins': 5},
             'Hawaii': {'Latitude': 19.699575, 'Longitude': -155.080872, 'Rank': 107, 'Wins': 9, 'Conf_wins': 5},
             'Houston': {'Latitude': 29.766083, 'Longitude': -95.35881, 'Rank': 53, 'Wins': 7, 'Conf_wins': 3},
             'Idaho': {'Latitude': 46.728709, 'Longitude': -117.012675, 'Rank': 42, 'Wins': 7, 'Conf_wins': 4},
             'Illinois': {'Latitude': 40.110558, 'Longitude': -88.228333, 'Rank': 35, 'Wins': 8, 'Conf_wins': 4},
             'Indiana': {'Latitude': 39.16806, 'Longitude': -86.522485, 'Rank': 38, 'Wins': 4, 'Conf_wins': 3},
             'Iowa': {'Latitude': 41.662607, 'Longitude': -91.55496, 'Rank': 40, 'Wins': 1, 'Conf_wins': 0},
             'IowaState': {'Latitude': 42.026511, 'Longitude': -93.646396, 'Rank': 14, 'Wins': 4, 'Conf_wins': 1},
             'Kansas': {'Latitude': 38.954343, 'Longitude': -95.255805, 'Rank': 13, 'Wins': 5, 'Conf_wins': 3},
             'KansasState': {'Latitude': 39.197221, 'Longitude': -96.585268, 'Rank': 11, 'Wins': 11, 'Conf_wins': 7},
             'Kent': {'Latitude': 41.149219, 'Longitude': -81.344644, 'Rank': 69, 'Wins': 2, 'Conf_wins': 2},
             'Kentucky': {'Latitude': 38.030602, 'Longitude': -84.50401, 'Rank': 98, 'Wins': 6, 'Conf_wins': 4},
             'LouisianaLafayette': {'Latitude': 30.211892, 'Longitude': -92.019939, 'Rank': 63, 'Wins': 2, 'Conf_wins': 0},
             'LouisianaMonroe': {'Latitude': 32.531076, 'Longitude': -92.067332, 'Rank': 58, 'Wins': 5, 'Conf_wins': 0},
             'LouisianaState': {'Latitude': 30.412331, 'Longitude': -91.183701, 'Rank': 106, 'Wins': 3, 'Conf_wins': 1},
             'LouisianaTech': {'Latitude': 32.530628, 'Longitude': -92.652078, 'Rank': 57, 'Wins': 8, 'Conf_wins': 0},
             'Louisville': {'Latitude': 38.21224, 'Longitude': -85.7589, 'Rank': 50, 'Wins': 7, 'Conf_wins': 4},
             'Marshall': {'Latitude': 38.42339, 'Longitude': -82.425003, 'Rank': 64, 'Wins': 13, 'Conf_wins': 8},
             'Maryland': {'Latitude': 38.987227, 'Longitude': -76.94249, 'Rank': 8, 'Wins': 5, 'Conf_wins': 2},
             'Memphis': {'Latitude': 35.118619, 'Longitude': -89.937385, 'Rank': 51, 'Wins': 5, 'Conf_wins': 4},
             'MiamiFlorida': {'Latitude': 25.717512, 'Longitude': -80.277861, 'Rank': 23, 'Wins': 9, 'Conf_wins': 6},
             'MiamiOhio': {'Latitude': 39.50831, 'Longitude': -84.734878, 'Rank': 65, 'Wins': 7, 'Conf_wins': 6},
             'Michigan': {'Latitude': 42.278046, 'Longitude': -83.73822, 'Rank': 31, 'Wins': 10, 'Conf_wins': 6},
             'MichiganState': {'Latitude': 42.701329, 'Longitude': -84.481682, 'Rank': 32, 'Wins': 10, 'Conf_wins': 6},
             'MiddleTennesseeState': {'Latitude': 35.848536, 'Longitude': -86.367036, 'Rank': 62, 'Wins': 3, 'Conf_wins': 0},
             'Minnesota': {'Latitude': 44.973829, 'Longitude': -93.227746, 'Rank': 34, 'Wins': 8, 'Conf_wins': 5},
             'Mississippi': {'Latitude': 34.364639, 'Longitude': -89.538196, 'Rank': 104, 'Wins': 8, 'Conf_wins': 4},
             'MississippiState': {'Latitude': 33.455108, 'Longitude': -88.794282, 'Rank': 102, 'Wins': 10, 'Conf_wins': 6},
             'Missouri': {'Latitude': 38.940289, 'Longitude': -92.32778, 'Rank': 15, 'Wins': 4, 'Conf_wins': 1},
             'Navy': {'Latitude': 38.980584, 'Longitude': -76.483799, 'Rank': 59, 'Wins': 5, 'Conf_wins': 0},
             'Nebraska': {'Latitude': 40.820744, 'Longitude': -96.70047, 'Rank': 10, 'Wins': 12, 'Conf_wins': 7},
             'Nevada': {'Latitude': 39.542944, 'Longitude': -119.815582, 'Rank': 46, 'Wins': 3, 'Conf_wins': 2},
             'NevadaLasVegas': {'Latitude': 36.107308, 'Longitude': -115.143755, 'Rank': 84, 'Wins': 3, 'Conf_wins': 1},
             'NewMexico': {'Latitude': 35.084289, 'Longitude': -106.619873, 'Rank': 82, 'Wins': 4, 'Conf_wins': 3},
             'NewMexicoState': {'Latitude': 32.279044, 'Longitude': -106.749096, 'Rank': 43, 'Wins': 6, 'Conf_wins': 3},
             'NorthCarolina': {'Latitude': 35.904973, 'Longitude': -79.047128, 'Rank': 9, 'Wins': 3, 'Conf_wins': 2},
             'NorthCarolinaState': {'Latitude': 35.78462, 'Longitude': -78.682277, 'Rank': 6, 'Wins': 6, 'Conf_wins': 3},
             'NorthTexas': {'Latitude': 33.207397, 'Longitude': -97.152722, 'Rank': 47, 'Wins': 2, 'Conf_wins': 1},
             'NorthernIllinois': {'Latitude': 41.934952, 'Longitude': -88.773479, 'Rank': 73, 'Wins': 5, 'Conf_wins': 5},
             'Northwestern': {'Latitude': 42.056446, 'Longitude': -87.675305, 'Rank': 39, 'Wins': 3, 'Conf_wins': 1},
             'NotreDame': {'Latitude': 41.69928, 'Longitude': -86.238899, 'Rank': 60, 'Wins': 5, 'Conf_wins': 0},
             'Ohio': {'Latitude': 39.32444, 'Longitude': -82.101163, 'Rank': 67, 'Wins': 5, 'Conf_wins': 5},
             'OhioState': {'Latitude': 40.006845, 'Longitude': -83.030194, 'Rank': 37, 'Wins': 6, 'Conf_wins': 3},
             'Oklahoma': {'Latitude': 35.205894, 'Longitude': -97.445717, 'Rank': 18, 'Wins': 7, 'Conf_wins': 5},
             'OklahomaState': {'Latitude': 36.127326, 'Longitude': -97.073649, 'Rank': 20, 'Wins': 5, 'Conf_wins': 3},
             'Oregon': {'Latitude': 44.044819, 'Longitude': -123.072593, 'Rank': 86, 'Wins': 9, 'Conf_wins': 6},
             'OregonState': {'Latitude': 44.563713, 'Longitude': -123.279478, 'Rank': 89, 'Wins': 7, 'Conf_wins': 4},
             'PennState': {'Latitude': 40.798214, 'Longitude': -77.859909, 'Rank': 33, 'Wins': 10, 'Conf_wins': 5},
             'Pittsburgh': {'Latitude': 40.444271, 'Longitude': -79.960914, 'Rank': 27, 'Wins': 5, 'Conf_wins': 2},
             'Purdue': {'Latitude': 40.423331, 'Longitude': -86.921044, 'Rank': 36, 'Wins': 7, 'Conf_wins': 4},
             'Rice': {'Latitude': 29.717154, 'Longitude': -95.404182, 'Rank': 110, 'Wins': 5, 'Conf_wins': 4},
             'Rutgers': {'Latitude': 40.741713, 'Longitude': -74.174393, 'Rank': 29, 'Wins': 1, 'Conf_wins': 1},
             'SanDiegoState': {'Latitude': 32.774799, 'Longitude': -117.071869, 'Rank': 81, 'Wins': 5, 'Conf_wins': 3},
             'SanJoseState': {'Latitude': 37.334744, 'Longitude': -121.880932, 'Rank': 113, 'Wins': 3, 'Conf_wins': 1},
             'SouthCarolina': {'Latitude': 33.993428, 'Longitude': -81.029972, 'Rank': 100, 'Wins': 0, 'Conf_wins': 0},
             'SouthernCalifornia': {'Latitude': 34.022415, 'Longitude': -118.28553, 'Rank': 91, 'Wins': 6, 'Conf_wins': 3},
             'SouthernMethodist': {'Latitude': 32.840623, 'Longitude': -96.785097, 'Rank': 111, 'Wins': 4, 'Conf_wins': 3},
             'SouthernMississippi': {'Latitude': 31.329445, 'Longitude': -89.333121, 'Rank': 48, 'Wins': 9, 'Conf_wins': 6},
             'Stanford': {'Latitude': 37.42823, 'Longitude': -122.168861, 'Rank': 85, 'Wins': 8, 'Conf_wins': 7},
             'Syracuse': {'Latitude': 43.039365, 'Longitude': -76.135223, 'Rank': 25, 'Wins': 7, 'Conf_wins': 3},
             'Temple': {'Latitude': 39.981143, 'Longitude': -75.155393, 'Rank': 28, 'Wins': 2, 'Conf_wins': 2},
             'Tennessee': {'Latitude': 35.954331, 'Longitude': -83.929627, 'Rank': 96, 'Wins': 9, 'Conf_wins': 6},
             'Texas': {'Latitude': 30.284851, 'Longitude': -97.733988, 'Rank': 16, 'Wins': 9, 'Conf_wins': 6},
             'TexasA&M': {'Latitude': 30.615011, 'Longitude': -96.342476, 'Rank': 17, 'Wins': 8, 'Conf_wins': 5},
             'TexasChristian': {'Latitude': 32.707823, 'Longitude': -97.362845, 'Rank': 108, 'Wins': 8, 'Conf_wins': 5},
             'TexasElPaso': {'Latitude': 31.773088, 'Longitude': -106.50573, 'Rank': 112, 'Wins': 5, 'Conf_wins': 3},
             'TexasTech': {'Latitude': 33.579166, 'Longitude': -101.886909, 'Rank': 19, 'Wins': 6, 'Conf_wins': 5},
             'Toledo': {'Latitude': 41.657567, 'Longitude': -83.613857, 'Rank': 72, 'Wins': 6, 'Conf_wins': 5},
             'Tulane': {'Latitude': 29.940446, 'Longitude': -90.120071, 'Rank': 55, 'Wins': 3, 'Conf_wins': 1},
             'Tulsa': {'Latitude': 36.151898, 'Longitude': -95.944646, 'Rank': 114, 'Wins': 2, 'Conf_wins': 1},
             'UCLA': {'Latitude': 34.068886, 'Longitude': -118.445217, 'Rank': 93, 'Wins': 4, 'Conf_wins': 2},
             'Utah': {'Latitude': 40.764872, 'Longitude': -111.842281, 'Rank': 77, 'Wins': 9, 'Conf_wins': 5},
             'UtahState': {'Latitude': 41.745065, 'Longitude': -111.810536, 'Rank': 44, 'Wins': 4, 'Conf_wins': 3},
             'Vanderbilt': {'Latitude': 36.144051, 'Longitude': -86.800949, 'Rank': 99, 'Wins': 5, 'Conf_wins': 2},
             'Virginia': {'Latitude': 38.033554, 'Longitude': -78.50798, 'Rank': 3, 'Wins': 7, 'Conf_wins': 5},
             'VirginiaTech': {'Latitude': 37.228149, 'Longitude': -80.423163, 'Rank': 22, 'Wins': 11, 'Conf_wins': 7},
             'WakeForest': {'Latitude': 36.135232, 'Longitude': -80.279291, 'Rank': 5, 'Wins': 7, 'Conf_wins': 3},
             'Washington': {'Latitude': 47.655548, 'Longitude': -122.3032, 'Rank': 87, 'Wins': 7, 'Conf_wins': 6},
             'WashingtonState': {'Latitude': 46.731803, 'Longitude': -117.15442, 'Rank': 94, 'Wins': 3, 'Conf_wins': 1},
             'WestVirginia': {'Latitude': 39.648067, 'Longitude': -79.969881, 'Rank': 26, 'Wins': 4, 'Conf_wins': 3},
             'WesternMichigan': {'Latitude': 42.283771, 'Longitude': -85.610271, 'Rank': 71, 'Wins': 7, 'Conf_wins': 6},
             'Wisconsin': {'Latitude': 43.07651, 'Longitude': -89.412508, 'Rank': 30, 'Wins': 10, 'Conf_wins': 7},
             'Wyoming': {'Latitude': 41.31469, 'Longitude': -105.566624, 'Rank': 80, 'Wins': 7, 'Conf_wins': 4}}
             
node_df = pd.merge(node_df,pd.DataFrame(node_data).T,how='left',left_index=True,right_index=True)
node_df
# Out:
#                    conference   Latitude   Longitude   Rank  Wins  Conf_wins
# school
# AirForce                    7  38.996093 -104.857222   83.0   6.0        2.0
# Akron                       6  41.075346  -81.512184   66.0   7.0        5.0
# Alabama                     9  33.215775  -87.538261  101.0  10.0        7.0
# AlabamaBirmingham           4  33.501569  -86.805677   52.0   5.0        4.0
# Arizona                     8  32.248814 -110.987419   90.0   6.0        3.0
# ...                       ...        ...         ...    ...   ...        ...
# WashingtonState             8  46.731803 -117.154420   94.0   3.0        1.0
# WestVirginia                1  39.648067  -79.969881   26.0   4.0        3.0
# WesternMichigan             6  42.283771  -85.610271   71.0   7.0        6.0
# Wisconsin                   2  43.076510  -89.412508   30.0  10.0        7.0
# Wyoming                     7  41.314690 -105.566624   80.0   7.0        4.0
#
# [115 rows x 6 columns]

# %% [markdown]
# ##### Add conference dummy variables for prediction

# %%
node_df['conf'] = node_df['conference']
node_df = pd.get_dummies(node_df, columns=['conf'])
node_df
# Out:
#                    conference   Latitude   Longitude   Rank  Wins  Conf_wins  \
# school
# AirForce                    7  38.996093 -104.857222   83.0   6.0        2.0
# Akron                       6  41.075346  -81.512184   66.0   7.0        5.0
# Alabama                     9  33.215775  -87.538261  101.0  10.0        7.0
# AlabamaBirmingham           4  33.501569  -86.805677   52.0   5.0        4.0
# Arizona                     8  32.248814 -110.987419   90.0   6.0        3.0
# ...                       ...        ...         ...    ...   ...        ...
# WashingtonState             8  46.731803 -117.154420   94.0   3.0        1.0
# WestVirginia                1  39.648067  -79.969881   26.0   4.0        3.0
# WesternMichigan             6  42.283771  -85.610271   71.0   7.0        6.0
# Wisconsin                   2  43.076510  -89.412508   30.0  10.0        7.0
# Wyoming                     7  41.314690 -105.566624   80.0   7.0        4.0
#
#                    conf_0  conf_1  conf_2  conf_3  conf_4  conf_5  conf_6  \
# school
# AirForce                0       0       0       0       0       0       0
# Akron                   0       0       0       0       0       0       1
# Alabama                 0       0       0       0       0       0       0
# AlabamaBirmingham       0       0       0       0       1       0       0
# Arizona                 0       0       0       0       0       0       0
# ...                   ...     ...     ...     ...     ...     ...     ...
# WashingtonState         0       0       0       0       0       0       0
# WestVirginia            0       1       0       0       0       0       0
# WesternMichigan         0       0       0       0       0       0       1
# Wisconsin               0       0       1       0       0       0       0
# Wyoming                 0       0       0       0       0       0       0
#
#                    conf_7  conf_8  conf_9  conf_10  conf_11
# school
# AirForce                1       0       0        0        0
# Akron                   0       0       0        0        0
# Alabama                 0       0       1        0        0
# AlabamaBirmingham       0       0       0        0        0
# Arizona                 0       1       0        0        0
# ...                   ...     ...     ...      ...      ...
# WashingtonState         0       1       0        0        0
# WestVirginia            0       0       0        0        0
# WesternMichigan         0       0       0        0        0
# Wisconsin               0       0       0        0        0
# Wyoming                 1       0       0        0        0
#
# [115 rows x 18 columns]

# %% [markdown]
# ### Add edge features
# ##### Add euclidean distance between schools from lat-long coordinates.

# %%
def euclidean_dist(edge_df,node_df):
    edge_df = pd.merge(edge_df,node_df[['Latitude','Longitude']].rename(columns={'Latitude':'src_lat','Longitude':'src_lon'}),
                       how='left',left_on='source',right_index=True)

    edge_df = pd.merge(edge_df,node_df[['Latitude','Longitude']].rename(columns={'Latitude':'trg_lat','Longitude':'trg_lon'}),
                       how='left',left_on='target',right_index=True)
    
    edge_df['euclidean_dist'] = ((edge_df['trg_lat']-edge_df['src_lat'])**2 +
                                 (edge_df['trg_lon']-edge_df['src_lon'])**2)**0.5
    
    edge_df.drop(columns=['src_lat','src_lon','trg_lat','trg_lon'],inplace=True)
    return edge_df

edge_df = euclidean_dist(edge_df,node_df)
edge_df
# Out:
#              source         target  euclidean_dist
# 0      BrighamYoung   FloridaState       29.056695
# 1      BrighamYoung      NewMexico        7.210711
# 2      BrighamYoung  SanDiegoState        9.236102
# 3      BrighamYoung        Wyoming        6.174841
# 4      BrighamYoung           Utah        0.548490
# ..              ...            ...             ...
# 608         Clemson       Maryland        7.304303
# 609  NevadaLasVegas         Hawaii       43.176232
# 610      WakeForest       Maryland        4.389546
# 611     OregonState     California        6.769309
# 612  TexasChristian         Hawaii       59.165743
#
# [613 rows x 3 columns]

# %% [markdown]
# ##### Add name similarity score

# %%
def sim_metric(df, col1, col2):
    return SequenceMatcher(None, str(df[col1]).lower(), str(df[col2]).lower()).ratio()
edge_df['name_sim_score'] = edge_df.apply(sim_metric,args=('source','target'),axis=1)

edge_df.loc[edge_df['source']=="Washington",:]
# Out:
#          source           target  euclidean_dist  name_sim_score
# 410  Washington           Oregon        3.691792        0.375000
# 411  Washington         Stanford       10.228200        0.333333
# 412  Washington  WashingtonState        5.230988        0.800000
# 413  Washington     MiamiFlorida       47.406820        0.272727
# 414  Washington      OregonState        3.242308        0.285714
# 415  Washington       California        9.783797        0.300000

# %% [markdown]
# ### Add conference game edge target variable

# %%
edge_df = pd.merge(edge_df,node_df['conference'].to_frame().rename(columns={'conference':'conf_source'}),
                   how='left',left_on='source',right_index=True)
edge_df = pd.merge(edge_df,node_df['conference'].to_frame().rename(columns={'conference':'conf_target'}),
                   how='left',left_on='target',right_index=True)

edge_df['conference_game'] = 0
edge_df.loc[edge_df['conf_source'] == edge_df['conf_target'], 'conference_game'] = 1
edge_df.drop(columns=['conf_source','conf_target'], inplace=True)
edge_df
# Out:
#              source         target  euclidean_dist  name_sim_score  \
# 0      BrighamYoung   FloridaState       29.056695        0.250000
# 1      BrighamYoung      NewMexico        7.210711        0.190476
# 2      BrighamYoung  SanDiegoState        9.236102        0.240000
# 3      BrighamYoung        Wyoming        6.174841        0.421053
# 4      BrighamYoung           Utah        0.548490        0.125000
# ..              ...            ...             ...             ...
# 608         Clemson       Maryland        7.304303        0.266667
# 609  NevadaLasVegas         Hawaii       43.176232        0.200000
# 610      WakeForest       Maryland        4.389546        0.222222
# 611     OregonState     California        6.769309        0.380952
# 612  TexasChristian         Hawaii       59.165743        0.300000
#
#      conference_game
# 0                  0
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ..               ...
# 608                1
# 609                0
# 610                1
# 611                1
# 612                0
#
# [613 rows x 5 columns]

# %% [markdown]
# ### Draw Data On Map

# %%
def draw_map(graph,edge_df,node_df,nodes='all',size=[12,9]):
    plt.rcParams["figure.figsize"]=size
    m = Basemap(projection='merc',llcrnrlon=-127,llcrnrlat=23,urcrnrlon=-65,urcrnrlat=50,lat_ts=0,resolution='l',suppress_ticks=True)
    m.drawmapboundary(fill_color='#A6CAE0', linewidth=1)
    m.fillcontinents(color='#F1ECEB', alpha=0.7, lake_color='#76B6D8')
    m.drawcoastlines(linewidth=0.1, color="white")
    m.drawcountries(linewidth = 0.5)
    m.drawstates(linewidth = 0.1)

    map_df = pd.merge(edge_df,node_df[['Latitude','Longitude']]
                      .rename(columns={'Latitude':'src_lat','Longitude':'src_lon'}),
                      how='left',left_on='source',right_index=True)

    map_df = pd.merge(map_df,node_df[['Latitude','Longitude']]
                      .rename(columns={'Latitude':'trg_lat','Longitude':'trg_lon'}),
                      how='left',left_on='target',right_index=True)
    
    for idx, row in map_df.iterrows():
        if row.euclidean_dist > 0.5:
            if row.conference_game == 1:
                m.drawgreatcircle(row.src_lon, row.src_lat, row.trg_lon, row.trg_lat, linewidth=0.5, color='#E75132')
            else:
                m.drawgreatcircle(row.src_lon, row.src_lat, row.trg_lon, row.trg_lat, linewidth=0.5, color='#69b3a2')

    mx,my=m(node_df['Longitude'],node_df['Latitude'])
    node_map = mx.to_frame()
    node_map['Latitude'] = my
    location = dict(zip(node_df.index,node_map.values))

    cmap = {0:'#bd2309', 1:'#bbb12d',2:'#1480fa',3:'#14fa2f',4:'#faf214',
            5:'#2edfea',6:'#ea2ec4',7:'#ea2e40',8:'#577a4d',9:'#2e46c0',
            10:'#f59422',11:'#8086d9'}
    
    if nodes == 'all':
        nodes = graph.nodes()
    
    colors = [cmap[graph.nodes[n]['value']] for n in nodes]
    nx.draw_networkx_nodes(graph, location, nodelist=nodes,node_color=colors, node_size=50)

draw_map(G,edge_df,node_df,nodes='all')

# %% [markdown]
# ### Train/Test Splits

# %%
node_train, node_test = train_test_split(node_df,test_size=0.15,random_state=42)
edge_train = edge_df.loc[~((edge_df['source'].isin(node_test.index)) | (edge_df['target'].isin(node_test.index)))]
edge_test = edge_df.loc[(edge_df['source'].isin(node_test.index)) | (edge_df['target'].isin(node_test.index))]

# %% [markdown]
# ### Add Bidirectional Duplication & Source-Target Index

# %%
def bidirectional(edge_df):
    reverse_df = edge_df.rename(columns={'source':'target','target':'source'})
    reverse_df = reverse_df[edge_df.columns]
    reverse_df = pd.concat([edge_df, reverse_df], ignore_index=True, axis=0)
    return reverse_df

def create_adj_id(node_df,edge_df):
    node_df = node_df.reset_index().reset_index()
    edge_df = pd.merge(edge_df,node_df[['school','index']].rename(columns={"index":"source_id"}),
                       how='left',left_on='source',right_on='school').drop(columns=['school'])
    edge_df = pd.merge(edge_df,node_df[['school','index']].rename(columns={"index":"target_id"}),
                       how='left',left_on='target',right_on='school').drop(columns=['school'])
    
    edge_df.dropna(inplace=True)
    return node_df, edge_df

edge_full_adj = bidirectional(edge_df)
edge_train_adj = bidirectional(edge_train)

node_full_adj,edge_full_adj = create_adj_id(node_df,edge_full_adj)
node_train_adj,edge_train_adj = create_adj_id(node_train,edge_train_adj)

# %% [markdown]
# ### Create Graph Tensors

# %%
def create_graph_tensor(node_df,edge_df):
    graph_tensor = tfgnn.GraphTensor.from_pieces(
        node_sets = {
            "schools": tfgnn.NodeSet.from_fields(
                sizes = [len(node_df)],
                features ={
                    'Latitude': np.array(node_df['Latitude'], dtype='float32').reshape(len(node_df),1),
                    'Longitude': np.array(node_df['Longitude'], dtype='float32').reshape(len(node_df),1),
                    'Rank': np.array(node_df['Rank'], dtype='int32').reshape(len(node_df),1),
                    'Wins': np.array(node_df['Wins'], dtype='int32').reshape(len(node_df),1),
                    'Conf_wins': np.array(node_df['Conf_wins'], dtype='int32').reshape(len(node_df),1),
                    'conference': np.array(node_df.iloc[:,-12:], dtype='int32'),
                }),
        },
        edge_sets ={
            "games": tfgnn.EdgeSet.from_fields(
                sizes = [len(edge_df)],
                features = {
                    'name_sim_score': np.array(edge_df['name_sim_score'], dtype='float32').reshape(len(edge_df),1),
                    'euclidean_dist': np.array(edge_df['euclidean_dist'], dtype='float32').reshape(len(edge_df),1),
                    'conference_game': np.array(edge_df['conference_game'], dtype='int32').reshape(len(edge_df),1)
                },
                adjacency = tfgnn.Adjacency.from_indices(
                    source = ("schools", np.array(edge_df['source_id'], dtype='int32')),
                    target = ("schools", np.array(edge_df['target_id'], dtype='int32')),
                )),
        })
    return graph_tensor

full_tensor = create_graph_tensor(node_full_adj,edge_full_adj)
train_tensor = create_graph_tensor(node_train_adj,edge_train_adj)

# %% [markdown]
# ### Create TensorFlow Datasets

# %%
def node_batch_merge(graph):
    graph = graph.merge_batch_to_components()
    node_features = graph.node_sets['schools'].get_features_dict()
    edge_features = graph.edge_sets['games'].get_features_dict()
    
    label = node_features.pop('conference')
    _ = edge_features.pop('conference_game')
    
    new_graph = graph.replace_features(
        node_sets={'schools':node_features},
        edge_sets={'games':edge_features})
    return new_graph, label

def edge_batch_merge(graph):
    graph = graph.merge_batch_to_components()
    node_features = graph.node_sets['schools'].get_features_dict()
    edge_features = graph.edge_sets['games'].get_features_dict()
    
    _ = node_features.pop('conference')
    label = edge_features.pop('conference_game')
    
    new_graph = graph.replace_features(
        node_sets={'schools':node_features},
        edge_sets={'games':edge_features})
    return new_graph, label

def create_dataset(graph,function):
    dataset = tf.data.Dataset.from_tensors(graph)
    dataset = dataset.batch(32)
    return dataset.map(function)

#Node Datasets
full_node_dataset = create_dataset(full_tensor,node_batch_merge)
train_node_dataset = create_dataset(train_tensor,node_batch_merge)

#Edge Datasets
full_edge_dataset = create_dataset(full_tensor,edge_batch_merge)
train_edge_dataset = create_dataset(train_tensor,edge_batch_merge)

# %% [markdown]
# # Modeling
# ### Build Model Inputs

# %%
def set_initial_node_state(node_set, node_set_name):
    features = [
        tf.keras.layers.Dense(32,activation="relu")(node_set['Latitude']),
        tf.keras.layers.Dense(32,activation="relu")(node_set['Longitude']),
        tf.keras.layers.Dense(32,activation="relu")(node_set['Rank']),
        tf.keras.layers.Dense(32,activation="relu")(node_set['Wins']),
        tf.keras.layers.Dense(32,activation="relu")(node_set['Conf_wins'])
    ]
    return tf.keras.layers.Concatenate()(features)

def set_initial_edge_state(edge_set, edge_set_name):
    features = [
        tf.keras.layers.Dense(32,activation="relu")(edge_set['name_sim_score']),
        tf.keras.layers.Dense(32,activation="relu")(edge_set['euclidean_dist'])
    ]
    return tf.keras.layers.Concatenate()(features)

graph_spec = train_node_dataset.element_spec[0]
input_graph = tf.keras.layers.Input(type_spec=graph_spec)

graph = tfgnn.keras.layers.MapFeatures(
    node_sets_fn=set_initial_node_state,
    edge_sets_fn=set_initial_edge_state
)(input_graph)
# Out:
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>

# %% [markdown]
# ### Build Graph Updates

# %%
def dense_layer(self,units=64,l2_reg=0.1,dropout=0.25,activation='relu'):
    regularizer = tf.keras.regularizers.l2(l2_reg)
    return tf.keras.Sequential([
        tf.keras.layers.Dense(units,
                              kernel_regularizer=regularizer,
                              bias_regularizer=regularizer),
        tf.keras.layers.Dropout(dropout)])
    
graph_updates = 3
for i in range(graph_updates):
    graph = tfgnn.keras.layers.GraphUpdate(
        node_sets = {
            'schools': tfgnn.keras.layers.NodeSetUpdate({
                'games': tfgnn.keras.layers.SimpleConv(
                    message_fn = dense_layer(32),
                    reduce_type="sum",
                    receiver_tag=tfgnn.TARGET)},
                tfgnn.keras.layers.NextStateFromConcat(
                    dense_layer(64)))})(graph)
    
    logits = tf.keras.layers.Dense(12,activation='softmax')(graph.node_sets["schools"][tfgnn.HIDDEN_STATE])

node_model = tf.keras.Model(input_graph, logits)

# %% [markdown]
# ##### Compile model

# %%
node_model.compile(
    tf.keras.optimizers.Adam(learning_rate=0.01),
    loss = 'categorical_crossentropy',
    metrics = ['categorical_accuracy']
)

node_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [()]                      0
#
#  map_features (MapFeatures)  ()                        448
#
#  graph_update (GraphUpdate)  ()                        34944
#
#  graph_update_1 (GraphUpdate  ()                       16512
#  )
#
#  graph_update_2 (GraphUpdate  ()                       16512
#  )
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
#  input.node_sets_2 (Instance  {'schools': ()}          0
#  Property)
#
#  input._get_features_ref_9 (  {'hidden_state': (None,   0
#  InstanceProperty)           64)}
#
#  dense_8 (Dense)             (None, 12)                780
#
# =================================================================
# Total params: 69,196
# Trainable params: 69,196
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train Model

# %%
es = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',mode='min',verbose=1,
        patience=10,restore_best_weights=True)

node_model.fit(train_node_dataset.repeat(),
               validation_data=full_node_dataset,
               steps_per_epoch=10,
               epochs=1000,
               callbacks=[es])
# Out:
# Epoch 1/1000
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/graph_update_2/node_set_update_2/simple_conv_2/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/graph_update_2/node_set_update_2/simple_conv_2/Reshape_1:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/graph_update_2/node_set_update_2/simple_conv_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/graph_update_2/node_set_update_2/simple_conv_2/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/graph_update_2/node_set_update_2/simple_conv_2/Reshape_3:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/graph_update_2/node_set_update_2/simple_conv_2/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/graph_update_1/node_set_update_1/simple_conv_1/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/graph_update_1/node_set_update_1/simple_conv_1/Reshape_1:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/graph_update_1/node_set_update_1/simple_conv_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/graph_update_1/node_set_update_1/simple_conv_1/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/graph_update_1/node_set_update_1/simple_conv_1/Reshape_3:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model/graph_update_1/node_set_update_1/simple_conv_1/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/graph_update/node_set_update/simple_conv/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/graph_update/node_set_update/simple_conv/Reshape_1:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model/graph_update/node_set_update/simple_conv/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model/graph_update/node_set_update/simple_conv/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model/graph_update/node_set_update/simple_conv/Reshape_3:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model/graph_update/node_set_update/simple_conv/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/kernel:0', 'dense_5/bias:0', 'dense_6/kernel:0', 'dense_6/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/kernel:0', 'dense_5/bias:0', 'dense_6/kernel:0', 'dense_6/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 10/10 [==============================] - 2s 64ms/step - loss: 40930.2422 - categorical_accuracy: 0.1144 - val_loss: 23167.8379 - val_categorical_accuracy: 0.1130
# Epoch 2/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 8358.6797 - categorical_accuracy: 0.1701 - val_loss: 2796.5759 - val_categorical_accuracy: 0.3217
# Epoch 3/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 2768.8276 - categorical_accuracy: 0.2619 - val_loss: 2296.1165 - val_categorical_accuracy: 0.3043
# Epoch 4/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 1129.1870 - categorical_accuracy: 0.3928 - val_loss: 1131.2008 - val_categorical_accuracy: 0.4087
# Epoch 5/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 851.8091 - categorical_accuracy: 0.4062 - val_loss: 1206.8578 - val_categorical_accuracy: 0.5739
# Epoch 6/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 587.5136 - categorical_accuracy: 0.4918 - val_loss: 1049.9724 - val_categorical_accuracy: 0.5043
# Epoch 7/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 486.3952 - categorical_accuracy: 0.5361 - val_loss: 580.5449 - val_categorical_accuracy: 0.5391
# Epoch 8/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 423.6621 - categorical_accuracy: 0.5330 - val_loss: 327.7157 - val_categorical_accuracy: 0.6000
# Epoch 9/1000
# 10/10 [==============================] - 0s 27ms/step - loss: 351.4596 - categorical_accuracy: 0.5124 - val_loss: 674.5601 - val_categorical_accuracy: 0.4174
# Epoch 10/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 338.6698 - categorical_accuracy: 0.4701 - val_loss: 427.4248 - val_categorical_accuracy: 0.4783
# Epoch 11/1000
# 10/10 [==============================] - 0s 27ms/step - loss: 254.1190 - categorical_accuracy: 0.5515 - val_loss: 622.5559 - val_categorical_accuracy: 0.4435
# Epoch 12/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 224.1729 - categorical_accuracy: 0.5567 - val_loss: 425.9016 - val_categorical_accuracy: 0.4783
# Epoch 13/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 192.9133 - categorical_accuracy: 0.5876 - val_loss: 510.4171 - val_categorical_accuracy: 0.4435
# Epoch 14/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 179.3363 - categorical_accuracy: 0.5948 - val_loss: 814.0414 - val_categorical_accuracy: 0.4087
# Epoch 15/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 165.5539 - categorical_accuracy: 0.6186 - val_loss: 540.8056 - val_categorical_accuracy: 0.4261
# Epoch 16/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 156.2793 - categorical_accuracy: 0.6021 - val_loss: 405.9289 - val_categorical_accuracy: 0.5043
# Epoch 17/1000
# 10/10 [==============================] - 0s 27ms/step - loss: 164.6369 - categorical_accuracy: 0.6021 - val_loss: 685.7186 - val_categorical_accuracy: 0.3304
# Epoch 18/1000
# 10/10 [==============================] - ETA: 0s - loss: 175.8991 - categorical_accuracy: 0.5629Restoring model weights from the end of the best epoch: 8.
# 10/10 [==============================] - 1s 55ms/step - loss: 175.8991 - categorical_accuracy: 0.5629 - val_loss: 387.0791 - val_categorical_accuracy: 0.5217
# Epoch 18: early stopping

# %% [markdown]
# ### Evaluate Results

# %%
### Add raw prediction ####
yhat = node_model.predict(full_node_dataset)
yhat_df = node_full_adj.set_index('school').iloc[:,-12:].copy()
yhat_df.iloc[:,:] = yhat
    
### Classify max of softmax output ###
yhat_df = yhat_df.apply(lambda x: x == x.max(), axis=1).astype(int)
    
### Merge output back to single column ###
yhat_df = yhat_df.dot(yhat_df.columns).to_frame().rename(columns={0:"conf_yhat"})
yhat_df = yhat_df['conf_yhat'].str.replace('conf_', '').astype(int).to_frame()
yhat_df['conf_actual'] = node_full_adj.set_index('school')['conference']
    
### Filter down to test nodes ###
yhat_df = yhat_df.loc[yhat_df.index.isin(node_test.index)]
    
### Calculate accuracy ###
yhat_df['Accuracy'] = yhat_df['conf_yhat']==yhat_df['conf_actual']
print("node accuracy:",yhat_df['Accuracy'].mean())
# Out:
# 1/1 [==============================] - 1s 579ms/step
# node accuracy: 0.2222222222222222

# %% [markdown]
# ##### The model trained successfully but they results are not great. Do not worry, accuracy will get much better when we tune the model later.
# ### Edge Model

# %%
graph_spec = train_node_dataset.element_spec[0]
input_graph = tf.keras.layers.Input(type_spec=graph_spec)

graph = tfgnn.keras.layers.MapFeatures(
    node_sets_fn=set_initial_node_state,
    edge_sets_fn=set_initial_edge_state
)(input_graph)

graph_updates = 3
for i in range(graph_updates):
    graph = tfgnn.keras.layers.GraphUpdate(
        edge_sets = {'games': tfgnn.keras.layers.EdgeSetUpdate(
            next_state = tfgnn.keras.layers.NextStateFromConcat(
                dense_layer(64,activation='relu')))},
        node_sets = {
            'schools': tfgnn.keras.layers.NodeSetUpdate({
                'games': tfgnn.keras.layers.SimpleConv(
                    message_fn = dense_layer(32),
                    reduce_type="sum",
                    receiver_tag=tfgnn.TARGET)},
                tfgnn.keras.layers.NextStateFromConcat(
                    dense_layer(64)))})(graph)

    logits = tf.keras.layers.Dense(1,activation='sigmoid')(graph.edge_sets["games"][tfgnn.HIDDEN_STATE])

edge_model = tf.keras.Model(input_graph, logits)

# %% [markdown]
# ### Compile Model

# %%
edge_model.compile(
    tf.keras.optimizers.Adam(learning_rate=0.01),
    loss = 'binary_crossentropy',
    metrics = ['Accuracy']
)

edge_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [()]                      0
#
#  map_features_1 (MapFeatures  ()                       448
#  )
#
#  graph_update_3 (GraphUpdate  ()                       59584
#  )
#
#  graph_update_4 (GraphUpdate  ()                       28864
#  )
#
#  graph_update_5 (GraphUpdate  ()                       28864
#  )
#
#  input.edge_sets_2 (Instance  {'games': ()}            0
#  Property)
#
#  input._get_features_ref_19   {'hidden_state': (None,   0
#  (InstanceProperty)          64)}
#
#  dense_20 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 117,825
# Trainable params: 117,825
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train Model

# %%
edge_model.fit(train_edge_dataset.repeat(),
               validation_data=full_edge_dataset,
               steps_per_epoch=10,
               epochs=1000,
               callbacks=[es])
# Out:
# Epoch 1/1000
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("Adam/gradients/concat_1:0", shape=(None,), dtype=int32), values=Tensor("Adam/gradients/concat:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/graph_update_5/edge_set_update_2/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/graph_update_4/edge_set_update_1/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/graph_update_4/edge_set_update_1/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/graph_update_4/edge_set_update_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/graph_update_4/edge_set_update_1/Reshape_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/graph_update_4/edge_set_update_1/Reshape_2:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/graph_update_4/edge_set_update_1/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/graph_update_4/node_set_update_4/simple_conv_4/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/graph_update_4/node_set_update_4/simple_conv_4/Reshape_1:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/graph_update_4/node_set_update_4/simple_conv_4/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/graph_update_4/node_set_update_4/simple_conv_4/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/graph_update_4/node_set_update_4/simple_conv_4/Reshape_3:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/graph_update_4/node_set_update_4/simple_conv_4/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/graph_update_3/edge_set_update/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/graph_update_3/edge_set_update/Reshape:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/graph_update_3/edge_set_update/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/graph_update_3/edge_set_update/Reshape_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/graph_update_3/edge_set_update/Reshape_2:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/graph_update_3/edge_set_update/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/graph_update_3/node_set_update_3/simple_conv_3/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/graph_update_3/node_set_update_3/simple_conv_3/Reshape_1:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/graph_update_3/node_set_update_3/simple_conv_3/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_1/graph_update_3/node_set_update_3/simple_conv_3/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_1/graph_update_3/node_set_update_3/simple_conv_3/Reshape_3:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_1/graph_update_3/node_set_update_3/simple_conv_3/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 10/10 [==============================] - 4s 146ms/step - loss: 5090.5635 - Accuracy: 0.5240 - val_loss: 2545.0366 - val_Accuracy: 0.3573
# Epoch 2/1000
# 10/10 [==============================] - 1s 89ms/step - loss: 1067.2131 - Accuracy: 0.5416 - val_loss: 519.6085 - val_Accuracy: 0.6427
# Epoch 3/1000
# 10/10 [==============================] - 1s 85ms/step - loss: 316.9055 - Accuracy: 0.5584 - val_loss: 263.8400 - val_Accuracy: 0.3573
# Epoch 4/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 143.1038 - Accuracy: 0.5406 - val_loss: 109.2459 - val_Accuracy: 0.6427
# Epoch 5/1000
# 10/10 [==============================] - 0s 47ms/step - loss: 91.5465 - Accuracy: 0.5613 - val_loss: 56.6792 - val_Accuracy: 0.5212
# Epoch 6/1000
# 10/10 [==============================] - 0s 48ms/step - loss: 71.9588 - Accuracy: 0.5741 - val_loss: 51.9688 - val_Accuracy: 0.6338
# Epoch 7/1000
# 10/10 [==============================] - 0s 46ms/step - loss: 64.5156 - Accuracy: 0.5468 - val_loss: 58.5601 - val_Accuracy: 0.6427
# Epoch 8/1000
# 10/10 [==============================] - 0s 44ms/step - loss: 59.5048 - Accuracy: 0.5717 - val_loss: 52.2175 - val_Accuracy: 0.6403
# Epoch 9/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 56.8268 - Accuracy: 0.5580 - val_loss: 53.1551 - val_Accuracy: 0.6427
# Epoch 10/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 54.5846 - Accuracy: 0.5774 - val_loss: 50.5804 - val_Accuracy: 0.6403
# Epoch 11/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 52.8056 - Accuracy: 0.5552 - val_loss: 49.1351 - val_Accuracy: 0.6427
# Epoch 12/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 50.9745 - Accuracy: 0.5700 - val_loss: 47.4391 - val_Accuracy: 0.6427
# Epoch 13/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 50.0430 - Accuracy: 0.5627 - val_loss: 46.0648 - val_Accuracy: 0.6427
# Epoch 14/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 48.7402 - Accuracy: 0.5512 - val_loss: 46.1833 - val_Accuracy: 0.6427
# Epoch 15/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 47.6698 - Accuracy: 0.5664 - val_loss: 44.5555 - val_Accuracy: 0.6427
# Epoch 16/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 46.4309 - Accuracy: 0.5666 - val_loss: 44.8373 - val_Accuracy: 0.6427
# Epoch 17/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 45.5219 - Accuracy: 0.5673 - val_loss: 42.9746 - val_Accuracy: 0.6427
# Epoch 18/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 44.6660 - Accuracy: 0.5654 - val_loss: 43.3709 - val_Accuracy: 0.6427
# Epoch 19/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 43.9170 - Accuracy: 0.5652 - val_loss: 42.0908 - val_Accuracy: 0.6427
# Epoch 20/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 42.9312 - Accuracy: 0.5724 - val_loss: 41.2298 - val_Accuracy: 0.6427
# Epoch 21/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 42.2237 - Accuracy: 0.5686 - val_loss: 40.1086 - val_Accuracy: 0.6427
# Epoch 22/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 41.6800 - Accuracy: 0.5600 - val_loss: 40.3506 - val_Accuracy: 0.6427
# Epoch 23/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 40.9883 - Accuracy: 0.5748 - val_loss: 38.7173 - val_Accuracy: 0.6427
# Epoch 24/1000
# 10/10 [==============================] - 0s 49ms/step - loss: 40.0607 - Accuracy: 0.5718 - val_loss: 38.9207 - val_Accuracy: 0.6427
# Epoch 25/1000
# 10/10 [==============================] - 0s 49ms/step - loss: 39.6073 - Accuracy: 0.5704 - val_loss: 37.9091 - val_Accuracy: 0.6427
# Epoch 26/1000
# 10/10 [==============================] - 0s 46ms/step - loss: 38.9370 - Accuracy: 0.5772 - val_loss: 38.1711 - val_Accuracy: 0.6427
# Epoch 27/1000
# 10/10 [==============================] - 0s 44ms/step - loss: 38.5012 - Accuracy: 0.5704 - val_loss: 38.0946 - val_Accuracy: 0.6427
# Epoch 28/1000
# 10/10 [==============================] - 0s 50ms/step - loss: 37.8084 - Accuracy: 0.5840 - val_loss: 36.5679 - val_Accuracy: 0.6427
# Epoch 29/1000
# 10/10 [==============================] - 0s 50ms/step - loss: 37.4016 - Accuracy: 0.5669 - val_loss: 36.3970 - val_Accuracy: 0.6427
# Epoch 30/1000
# 10/10 [==============================] - 0s 49ms/step - loss: 36.8624 - Accuracy: 0.5673 - val_loss: 35.4187 - val_Accuracy: 0.6427
# Epoch 31/1000
# 10/10 [==============================] - 0s 48ms/step - loss: 36.3338 - Accuracy: 0.5804 - val_loss: 35.2514 - val_Accuracy: 0.6427
# Epoch 32/1000
# 10/10 [==============================] - 0s 47ms/step - loss: 35.7889 - Accuracy: 0.5816 - val_loss: 34.8137 - val_Accuracy: 0.6427
# Epoch 33/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 35.3304 - Accuracy: 0.5805 - val_loss: 34.1862 - val_Accuracy: 0.6427
# Epoch 34/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 34.9100 - Accuracy: 0.5703 - val_loss: 33.7171 - val_Accuracy: 0.6427
# Epoch 35/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 34.6191 - Accuracy: 0.5765 - val_loss: 33.5759 - val_Accuracy: 0.6427
# Epoch 36/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 34.1626 - Accuracy: 0.5701 - val_loss: 32.8216 - val_Accuracy: 0.6427
# Epoch 37/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 33.6532 - Accuracy: 0.5771 - val_loss: 32.9994 - val_Accuracy: 0.6427
# Epoch 38/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 33.2844 - Accuracy: 0.5883 - val_loss: 32.3305 - val_Accuracy: 0.6427
# Epoch 39/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 32.9206 - Accuracy: 0.5655 - val_loss: 31.8483 - val_Accuracy: 0.6427
# Epoch 40/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 32.5297 - Accuracy: 0.5781 - val_loss: 31.4919 - val_Accuracy: 0.6427
# Epoch 41/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 32.0504 - Accuracy: 0.5868 - val_loss: 31.3406 - val_Accuracy: 0.6427
# Epoch 42/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 31.7661 - Accuracy: 0.5709 - val_loss: 30.9856 - val_Accuracy: 0.6427
# Epoch 43/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 31.4046 - Accuracy: 0.5828 - val_loss: 30.4543 - val_Accuracy: 0.6427
# Epoch 44/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 31.0856 - Accuracy: 0.5829 - val_loss: 30.6534 - val_Accuracy: 0.6427
# Epoch 45/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 30.8152 - Accuracy: 0.5771 - val_loss: 29.8552 - val_Accuracy: 0.6427
# Epoch 46/1000
# 10/10 [==============================] - 0s 45ms/step - loss: 30.4280 - Accuracy: 0.5871 - val_loss: 29.6055 - val_Accuracy: 0.6427
# Epoch 47/1000
# 10/10 [==============================] - 1s 56ms/step - loss: 30.1889 - Accuracy: 0.5752 - val_loss: 29.1902 - val_Accuracy: 0.6427
# Epoch 48/1000
# 10/10 [==============================] - 1s 93ms/step - loss: 29.8300 - Accuracy: 0.5884 - val_loss: 28.7594 - val_Accuracy: 0.6444
# Epoch 49/1000
# 10/10 [==============================] - 1s 48ms/step - loss: 29.4205 - Accuracy: 0.5816 - val_loss: 28.6493 - val_Accuracy: 0.6427
# Epoch 50/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 29.1476 - Accuracy: 0.5797 - val_loss: 28.4268 - val_Accuracy: 0.6427
# Epoch 51/1000
# 10/10 [==============================] - 0s 51ms/step - loss: 28.8462 - Accuracy: 0.5830 - val_loss: 28.1064 - val_Accuracy: 0.6427
# Epoch 52/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 28.6979 - Accuracy: 0.5722 - val_loss: 27.7736 - val_Accuracy: 0.6427
# Epoch 53/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 28.3585 - Accuracy: 0.5791 - val_loss: 27.5757 - val_Accuracy: 0.6427
# Epoch 54/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 28.0698 - Accuracy: 0.5781 - val_loss: 27.3158 - val_Accuracy: 0.6427
# Epoch 55/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 27.7474 - Accuracy: 0.5808 - val_loss: 26.9532 - val_Accuracy: 0.6419
# Epoch 56/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 27.5365 - Accuracy: 0.5812 - val_loss: 26.9662 - val_Accuracy: 0.6427
# Epoch 57/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 27.2201 - Accuracy: 0.5889 - val_loss: 26.8048 - val_Accuracy: 0.6427
# Epoch 58/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 27.0303 - Accuracy: 0.5768 - val_loss: 26.4196 - val_Accuracy: 0.6427
# Epoch 59/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 26.7473 - Accuracy: 0.5834 - val_loss: 26.1512 - val_Accuracy: 0.6427
# Epoch 60/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 26.4619 - Accuracy: 0.5906 - val_loss: 25.8799 - val_Accuracy: 0.6427
# Epoch 61/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 26.2313 - Accuracy: 0.5917 - val_loss: 25.5539 - val_Accuracy: 0.6419
# Epoch 62/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 25.9972 - Accuracy: 0.5838 - val_loss: 25.2856 - val_Accuracy: 0.6419
# Epoch 63/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 25.7388 - Accuracy: 0.5929 - val_loss: 25.1978 - val_Accuracy: 0.6427
# Epoch 64/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 25.5535 - Accuracy: 0.5812 - val_loss: 24.9761 - val_Accuracy: 0.6427
# Epoch 65/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 25.2983 - Accuracy: 0.5752 - val_loss: 24.8284 - val_Accuracy: 0.6427
# Epoch 66/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 25.0571 - Accuracy: 0.5947 - val_loss: 24.5176 - val_Accuracy: 0.6419
# Epoch 67/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 24.8525 - Accuracy: 0.5924 - val_loss: 24.3507 - val_Accuracy: 0.6427
# Epoch 68/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 24.6753 - Accuracy: 0.5883 - val_loss: 24.1213 - val_Accuracy: 0.6419
# Epoch 69/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 24.4235 - Accuracy: 0.5901 - val_loss: 24.0573 - val_Accuracy: 0.6427
# Epoch 70/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 24.2567 - Accuracy: 0.5909 - val_loss: 23.8482 - val_Accuracy: 0.6427
# Epoch 71/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 24.0863 - Accuracy: 0.5935 - val_loss: 23.7043 - val_Accuracy: 0.6427
# Epoch 72/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 23.8596 - Accuracy: 0.5925 - val_loss: 23.3815 - val_Accuracy: 0.6427
# Epoch 73/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 23.6572 - Accuracy: 0.5910 - val_loss: 23.2598 - val_Accuracy: 0.6427
# Epoch 74/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 23.4596 - Accuracy: 0.5899 - val_loss: 23.0826 - val_Accuracy: 0.6427
# Epoch 75/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 23.2652 - Accuracy: 0.5910 - val_loss: 22.9795 - val_Accuracy: 0.6427
# Epoch 76/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 23.0546 - Accuracy: 0.5956 - val_loss: 22.7052 - val_Accuracy: 0.6427
# Epoch 77/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 22.8704 - Accuracy: 0.5861 - val_loss: 22.5215 - val_Accuracy: 0.6427
# Epoch 78/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 22.6875 - Accuracy: 0.5940 - val_loss: 22.3536 - val_Accuracy: 0.6427
# Epoch 79/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 22.5368 - Accuracy: 0.5910 - val_loss: 22.2065 - val_Accuracy: 0.6427
# Epoch 80/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 22.3286 - Accuracy: 0.5995 - val_loss: 22.0244 - val_Accuracy: 0.6427
# Epoch 81/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 22.1718 - Accuracy: 0.5960 - val_loss: 21.8346 - val_Accuracy: 0.6427
# Epoch 82/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 21.9900 - Accuracy: 0.5915 - val_loss: 21.6471 - val_Accuracy: 0.6427
# Epoch 83/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 21.8036 - Accuracy: 0.6035 - val_loss: 21.5414 - val_Accuracy: 0.6427
# Epoch 84/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 21.6393 - Accuracy: 0.6076 - val_loss: 21.3660 - val_Accuracy: 0.6427
# Epoch 85/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 21.4747 - Accuracy: 0.6043 - val_loss: 21.1371 - val_Accuracy: 0.6419
# Epoch 86/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 21.3215 - Accuracy: 0.6000 - val_loss: 21.0970 - val_Accuracy: 0.6427
# Epoch 87/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 21.1582 - Accuracy: 0.5968 - val_loss: 20.9023 - val_Accuracy: 0.6427
# Epoch 88/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 21.0039 - Accuracy: 0.6012 - val_loss: 20.8357 - val_Accuracy: 0.6427
# Epoch 89/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 20.8591 - Accuracy: 0.6003 - val_loss: 20.5678 - val_Accuracy: 0.6427
# Epoch 90/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 20.6915 - Accuracy: 0.6008 - val_loss: 20.4109 - val_Accuracy: 0.6427
# Epoch 91/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 20.5402 - Accuracy: 0.6012 - val_loss: 20.2457 - val_Accuracy: 0.6427
# Epoch 92/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 20.3895 - Accuracy: 0.6066 - val_loss: 20.1149 - val_Accuracy: 0.6427
# Epoch 93/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 20.2457 - Accuracy: 0.6048 - val_loss: 19.9606 - val_Accuracy: 0.6427
# Epoch 94/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 20.1224 - Accuracy: 0.5990 - val_loss: 19.9218 - val_Accuracy: 0.6427
# Epoch 95/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 19.9792 - Accuracy: 0.6069 - val_loss: 19.6769 - val_Accuracy: 0.6444
# Epoch 96/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 19.8142 - Accuracy: 0.6087 - val_loss: 19.6200 - val_Accuracy: 0.6427
# Epoch 97/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 19.6817 - Accuracy: 0.6009 - val_loss: 19.3998 - val_Accuracy: 0.6436
# Epoch 98/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 19.5467 - Accuracy: 0.6053 - val_loss: 19.3021 - val_Accuracy: 0.6427
# Epoch 99/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 19.3912 - Accuracy: 0.6050 - val_loss: 19.2201 - val_Accuracy: 0.6427
# Epoch 100/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 19.2493 - Accuracy: 0.6096 - val_loss: 19.0125 - val_Accuracy: 0.6427
# Epoch 101/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 19.1227 - Accuracy: 0.6111 - val_loss: 18.9099 - val_Accuracy: 0.6427
# Epoch 102/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 18.9709 - Accuracy: 0.6143 - val_loss: 18.7472 - val_Accuracy: 0.6427
# Epoch 103/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 18.8558 - Accuracy: 0.6093 - val_loss: 18.6720 - val_Accuracy: 0.6427
# Epoch 104/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 18.7409 - Accuracy: 0.6107 - val_loss: 18.5443 - val_Accuracy: 0.6427
# Epoch 105/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 18.5764 - Accuracy: 0.6161 - val_loss: 18.4090 - val_Accuracy: 0.6427
# Epoch 106/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 18.4610 - Accuracy: 0.6130 - val_loss: 18.2403 - val_Accuracy: 0.6387
# Epoch 107/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 18.3630 - Accuracy: 0.6059 - val_loss: 18.1210 - val_Accuracy: 0.6427
# Epoch 108/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 18.1958 - Accuracy: 0.6184 - val_loss: 18.0213 - val_Accuracy: 0.6427
# Epoch 109/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 18.0732 - Accuracy: 0.6158 - val_loss: 17.9030 - val_Accuracy: 0.6427
# Epoch 110/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 17.9886 - Accuracy: 0.6113 - val_loss: 17.8181 - val_Accuracy: 0.6427
# Epoch 111/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 17.8343 - Accuracy: 0.6147 - val_loss: 17.7128 - val_Accuracy: 0.6427
# Epoch 112/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 17.7195 - Accuracy: 0.6177 - val_loss: 17.5660 - val_Accuracy: 0.6427
# Epoch 113/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 17.5944 - Accuracy: 0.6202 - val_loss: 17.4527 - val_Accuracy: 0.6427
# Epoch 114/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 17.4784 - Accuracy: 0.6169 - val_loss: 17.3114 - val_Accuracy: 0.6427
# Epoch 115/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 17.3559 - Accuracy: 0.6198 - val_loss: 17.2053 - val_Accuracy: 0.6427
# Epoch 116/1000
# 10/10 [==============================] - 0s 27ms/step - loss: 17.2339 - Accuracy: 0.6278 - val_loss: 17.1141 - val_Accuracy: 0.6427
# Epoch 117/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 17.1319 - Accuracy: 0.6236 - val_loss: 16.9646 - val_Accuracy: 0.6427
# Epoch 118/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 17.0303 - Accuracy: 0.6133 - val_loss: 16.8685 - val_Accuracy: 0.6427
# Epoch 119/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 16.9032 - Accuracy: 0.6185 - val_loss: 16.7422 - val_Accuracy: 0.6427
# Epoch 120/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 16.7979 - Accuracy: 0.6214 - val_loss: 16.7408 - val_Accuracy: 0.6427
# Epoch 121/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 16.6707 - Accuracy: 0.6269 - val_loss: 16.5573 - val_Accuracy: 0.6427
# Epoch 122/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 16.5639 - Accuracy: 0.6214 - val_loss: 16.4233 - val_Accuracy: 0.6427
# Epoch 123/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 16.4478 - Accuracy: 0.6192 - val_loss: 16.3193 - val_Accuracy: 0.6427
# Epoch 124/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 16.3289 - Accuracy: 0.6269 - val_loss: 16.2332 - val_Accuracy: 0.6427
# Epoch 125/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 16.2209 - Accuracy: 0.6355 - val_loss: 16.1103 - val_Accuracy: 0.6427
# Epoch 126/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 16.1196 - Accuracy: 0.6322 - val_loss: 16.0429 - val_Accuracy: 0.6427
# Epoch 127/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 15.9962 - Accuracy: 0.6401 - val_loss: 15.8871 - val_Accuracy: 0.6427
# Epoch 128/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 15.9084 - Accuracy: 0.6297 - val_loss: 15.8059 - val_Accuracy: 0.6427
# Epoch 129/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 15.8011 - Accuracy: 0.6356 - val_loss: 15.6965 - val_Accuracy: 0.6427
# Epoch 130/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 15.6928 - Accuracy: 0.6317 - val_loss: 15.6219 - val_Accuracy: 0.6427
# Epoch 131/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 15.5876 - Accuracy: 0.6385 - val_loss: 15.5189 - val_Accuracy: 0.6427
# Epoch 132/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 15.4903 - Accuracy: 0.6391 - val_loss: 15.4073 - val_Accuracy: 0.6427
# Epoch 133/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 15.3906 - Accuracy: 0.6414 - val_loss: 15.2865 - val_Accuracy: 0.6427
# Epoch 134/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 15.2920 - Accuracy: 0.6268 - val_loss: 15.1983 - val_Accuracy: 0.6427
# Epoch 135/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 15.1864 - Accuracy: 0.6371 - val_loss: 15.0874 - val_Accuracy: 0.6427
# Epoch 136/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 15.0824 - Accuracy: 0.6395 - val_loss: 15.0299 - val_Accuracy: 0.6427
# Epoch 137/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 14.9845 - Accuracy: 0.6372 - val_loss: 14.9146 - val_Accuracy: 0.6427
# Epoch 138/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 14.8973 - Accuracy: 0.6341 - val_loss: 14.8198 - val_Accuracy: 0.6427
# Epoch 139/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 14.7951 - Accuracy: 0.6408 - val_loss: 14.7055 - val_Accuracy: 0.6427
# Epoch 140/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 14.6924 - Accuracy: 0.6375 - val_loss: 14.6142 - val_Accuracy: 0.6427
# Epoch 141/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 14.5942 - Accuracy: 0.6432 - val_loss: 14.5421 - val_Accuracy: 0.6427
# Epoch 142/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 14.5005 - Accuracy: 0.6366 - val_loss: 14.4056 - val_Accuracy: 0.6427
# Epoch 143/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 14.4164 - Accuracy: 0.6407 - val_loss: 14.3194 - val_Accuracy: 0.6427
# Epoch 144/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 14.3062 - Accuracy: 0.6465 - val_loss: 14.2375 - val_Accuracy: 0.6427
# Epoch 145/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 14.2145 - Accuracy: 0.6439 - val_loss: 14.1378 - val_Accuracy: 0.6427
# Epoch 146/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 14.1179 - Accuracy: 0.6454 - val_loss: 14.0622 - val_Accuracy: 0.6427
# Epoch 147/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 14.0393 - Accuracy: 0.6375 - val_loss: 13.9697 - val_Accuracy: 0.6427
# Epoch 148/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 13.9380 - Accuracy: 0.6459 - val_loss: 13.8671 - val_Accuracy: 0.6427
# Epoch 149/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 13.8472 - Accuracy: 0.6418 - val_loss: 13.8003 - val_Accuracy: 0.6427
# Epoch 150/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 13.7544 - Accuracy: 0.6506 - val_loss: 13.6794 - val_Accuracy: 0.6427
# Epoch 151/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 13.6693 - Accuracy: 0.6483 - val_loss: 13.5872 - val_Accuracy: 0.6427
# Epoch 152/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 13.5773 - Accuracy: 0.6495 - val_loss: 13.5061 - val_Accuracy: 0.6427
# Epoch 153/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 13.4829 - Accuracy: 0.6469 - val_loss: 13.4436 - val_Accuracy: 0.6427
# Epoch 154/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 13.3986 - Accuracy: 0.6522 - val_loss: 13.3419 - val_Accuracy: 0.6427
# Epoch 155/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 13.3075 - Accuracy: 0.6503 - val_loss: 13.2590 - val_Accuracy: 0.6427
# Epoch 156/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 13.2189 - Accuracy: 0.6476 - val_loss: 13.1649 - val_Accuracy: 0.6427
# Epoch 157/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 13.1351 - Accuracy: 0.6491 - val_loss: 13.1108 - val_Accuracy: 0.6427
# Epoch 158/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 13.0445 - Accuracy: 0.6516 - val_loss: 12.9892 - val_Accuracy: 0.6427
# Epoch 159/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 12.9608 - Accuracy: 0.6473 - val_loss: 12.9068 - val_Accuracy: 0.6427
# Epoch 160/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 12.8677 - Accuracy: 0.6577 - val_loss: 12.8363 - val_Accuracy: 0.6427
# Epoch 161/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 12.7890 - Accuracy: 0.6548 - val_loss: 12.7273 - val_Accuracy: 0.6427
# Epoch 162/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 12.7014 - Accuracy: 0.6559 - val_loss: 12.6733 - val_Accuracy: 0.6427
# Epoch 163/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 12.6279 - Accuracy: 0.6457 - val_loss: 12.5860 - val_Accuracy: 0.6427
# Epoch 164/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 12.5281 - Accuracy: 0.6585 - val_loss: 12.4884 - val_Accuracy: 0.6427
# Epoch 165/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 12.4532 - Accuracy: 0.6610 - val_loss: 12.3927 - val_Accuracy: 0.6427
# Epoch 166/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 12.3770 - Accuracy: 0.6467 - val_loss: 12.3443 - val_Accuracy: 0.6427
# Epoch 167/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 12.2933 - Accuracy: 0.6494 - val_loss: 12.2410 - val_Accuracy: 0.6427
# Epoch 168/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 12.2072 - Accuracy: 0.6616 - val_loss: 12.1613 - val_Accuracy: 0.6427
# Epoch 169/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 12.1171 - Accuracy: 0.6563 - val_loss: 12.0838 - val_Accuracy: 0.6427
# Epoch 170/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 12.0402 - Accuracy: 0.6582 - val_loss: 12.0174 - val_Accuracy: 0.6427
# Epoch 171/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 11.9595 - Accuracy: 0.6579 - val_loss: 11.9169 - val_Accuracy: 0.6427
# Epoch 172/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 11.8821 - Accuracy: 0.6578 - val_loss: 11.8497 - val_Accuracy: 0.6427
# Epoch 173/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 11.7990 - Accuracy: 0.6575 - val_loss: 11.7642 - val_Accuracy: 0.6427
# Epoch 174/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 11.7187 - Accuracy: 0.6613 - val_loss: 11.6898 - val_Accuracy: 0.6427
# Epoch 175/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 11.6426 - Accuracy: 0.6590 - val_loss: 11.6077 - val_Accuracy: 0.6427
# Epoch 176/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 11.5611 - Accuracy: 0.6577 - val_loss: 11.5427 - val_Accuracy: 0.6427
# Epoch 177/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 11.4809 - Accuracy: 0.6662 - val_loss: 11.4439 - val_Accuracy: 0.6427
# Epoch 178/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 11.4111 - Accuracy: 0.6585 - val_loss: 11.3851 - val_Accuracy: 0.6427
# Epoch 179/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 11.3280 - Accuracy: 0.6638 - val_loss: 11.2998 - val_Accuracy: 0.6427
# Epoch 180/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 11.2568 - Accuracy: 0.6626 - val_loss: 11.2156 - val_Accuracy: 0.6427
# Epoch 181/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 11.1770 - Accuracy: 0.6652 - val_loss: 11.1662 - val_Accuracy: 0.6427
# Epoch 182/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 11.1027 - Accuracy: 0.6607 - val_loss: 11.0649 - val_Accuracy: 0.6427
# Epoch 183/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 11.0217 - Accuracy: 0.6652 - val_loss: 11.0132 - val_Accuracy: 0.6427
# Epoch 184/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 10.9472 - Accuracy: 0.6638 - val_loss: 10.9216 - val_Accuracy: 0.6427
# Epoch 185/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 10.8735 - Accuracy: 0.6684 - val_loss: 10.8406 - val_Accuracy: 0.6427
# Epoch 186/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 10.8035 - Accuracy: 0.6575 - val_loss: 10.7837 - val_Accuracy: 0.6427
# Epoch 187/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 10.7270 - Accuracy: 0.6620 - val_loss: 10.7113 - val_Accuracy: 0.6427
# Epoch 188/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 10.6522 - Accuracy: 0.6650 - val_loss: 10.6236 - val_Accuracy: 0.6427
# Epoch 189/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 10.5763 - Accuracy: 0.6644 - val_loss: 10.5927 - val_Accuracy: 0.6427
# Epoch 190/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 10.5072 - Accuracy: 0.6644 - val_loss: 10.4775 - val_Accuracy: 0.6427
# Epoch 191/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 10.4358 - Accuracy: 0.6679 - val_loss: 10.4244 - val_Accuracy: 0.6427
# Epoch 192/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 10.3633 - Accuracy: 0.6677 - val_loss: 10.3396 - val_Accuracy: 0.6427
# Epoch 193/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 10.2892 - Accuracy: 0.6647 - val_loss: 10.2721 - val_Accuracy: 0.6427
# Epoch 194/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 10.2135 - Accuracy: 0.6677 - val_loss: 10.2051 - val_Accuracy: 0.6427
# Epoch 195/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 10.1444 - Accuracy: 0.6673 - val_loss: 10.1377 - val_Accuracy: 0.6427
# Epoch 196/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 10.0833 - Accuracy: 0.6625 - val_loss: 10.0554 - val_Accuracy: 0.6427
# Epoch 197/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 10.0085 - Accuracy: 0.6654 - val_loss: 9.9939 - val_Accuracy: 0.6427
# Epoch 198/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 9.9355 - Accuracy: 0.6694 - val_loss: 9.9234 - val_Accuracy: 0.6427
# Epoch 199/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 9.8664 - Accuracy: 0.6654 - val_loss: 9.8534 - val_Accuracy: 0.6427
# Epoch 200/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 9.7950 - Accuracy: 0.6688 - val_loss: 9.7953 - val_Accuracy: 0.6427
# Epoch 201/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 9.7289 - Accuracy: 0.6683 - val_loss: 9.7022 - val_Accuracy: 0.6427
# Epoch 202/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 9.6630 - Accuracy: 0.6676 - val_loss: 9.6655 - val_Accuracy: 0.6427
# Epoch 203/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 9.5934 - Accuracy: 0.6684 - val_loss: 9.5804 - val_Accuracy: 0.6427
# Epoch 204/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 9.5242 - Accuracy: 0.6698 - val_loss: 9.5001 - val_Accuracy: 0.6427
# Epoch 205/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 9.4632 - Accuracy: 0.6619 - val_loss: 9.4694 - val_Accuracy: 0.6427
# Epoch 206/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 9.3940 - Accuracy: 0.6678 - val_loss: 9.3668 - val_Accuracy: 0.6427
# Epoch 207/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 9.3288 - Accuracy: 0.6652 - val_loss: 9.3358 - val_Accuracy: 0.6427
# Epoch 208/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 9.2602 - Accuracy: 0.6676 - val_loss: 9.2449 - val_Accuracy: 0.6427
# Epoch 209/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 9.1937 - Accuracy: 0.6651 - val_loss: 9.1888 - val_Accuracy: 0.6427
# Epoch 210/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 9.1278 - Accuracy: 0.6723 - val_loss: 9.1217 - val_Accuracy: 0.6427
# Epoch 211/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 9.0617 - Accuracy: 0.6713 - val_loss: 9.0491 - val_Accuracy: 0.6427
# Epoch 212/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 8.9999 - Accuracy: 0.6702 - val_loss: 9.0058 - val_Accuracy: 0.6427
# Epoch 213/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 8.9354 - Accuracy: 0.6693 - val_loss: 8.9128 - val_Accuracy: 0.6427
# Epoch 214/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 8.8685 - Accuracy: 0.6655 - val_loss: 8.8674 - val_Accuracy: 0.6427
# Epoch 215/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 8.8032 - Accuracy: 0.6702 - val_loss: 8.7955 - val_Accuracy: 0.6427
# Epoch 216/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 8.7434 - Accuracy: 0.6658 - val_loss: 8.7575 - val_Accuracy: 0.6427
# Epoch 217/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 8.6774 - Accuracy: 0.6668 - val_loss: 8.6798 - val_Accuracy: 0.6427
# Epoch 218/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 8.6128 - Accuracy: 0.6709 - val_loss: 8.6157 - val_Accuracy: 0.6427
# Epoch 219/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 8.5539 - Accuracy: 0.6703 - val_loss: 8.5423 - val_Accuracy: 0.6427
# Epoch 220/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 8.4912 - Accuracy: 0.6693 - val_loss: 8.4808 - val_Accuracy: 0.6427
# Epoch 221/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 8.4280 - Accuracy: 0.6694 - val_loss: 8.4291 - val_Accuracy: 0.6427
# Epoch 222/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 8.3658 - Accuracy: 0.6714 - val_loss: 8.3671 - val_Accuracy: 0.6427
# Epoch 223/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 8.3061 - Accuracy: 0.6690 - val_loss: 8.3173 - val_Accuracy: 0.6427
# Epoch 224/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 8.2442 - Accuracy: 0.6678 - val_loss: 8.2342 - val_Accuracy: 0.6427
# Epoch 225/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 8.1816 - Accuracy: 0.6683 - val_loss: 8.1814 - val_Accuracy: 0.6427
# Epoch 226/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 8.1279 - Accuracy: 0.6683 - val_loss: 8.1235 - val_Accuracy: 0.6427
# Epoch 227/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 8.0673 - Accuracy: 0.6687 - val_loss: 8.0575 - val_Accuracy: 0.6427
# Epoch 228/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 8.0029 - Accuracy: 0.6715 - val_loss: 8.0173 - val_Accuracy: 0.6427
# Epoch 229/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 7.9458 - Accuracy: 0.6727 - val_loss: 7.9338 - val_Accuracy: 0.6427
# Epoch 230/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 7.8897 - Accuracy: 0.6677 - val_loss: 7.8869 - val_Accuracy: 0.6427
# Epoch 231/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 7.8309 - Accuracy: 0.6695 - val_loss: 7.8523 - val_Accuracy: 0.6427
# Epoch 232/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 7.7711 - Accuracy: 0.6709 - val_loss: 7.7668 - val_Accuracy: 0.6427
# Epoch 233/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 7.7143 - Accuracy: 0.6703 - val_loss: 7.7222 - val_Accuracy: 0.6427
# Epoch 234/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 7.6596 - Accuracy: 0.6727 - val_loss: 7.6656 - val_Accuracy: 0.6427
# Epoch 235/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 7.5997 - Accuracy: 0.6721 - val_loss: 7.5828 - val_Accuracy: 0.6427
# Epoch 236/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 7.5454 - Accuracy: 0.6671 - val_loss: 7.5551 - val_Accuracy: 0.6427
# Epoch 237/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 7.4853 - Accuracy: 0.6704 - val_loss: 7.5017 - val_Accuracy: 0.6427
# Epoch 238/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 7.4255 - Accuracy: 0.6721 - val_loss: 7.4203 - val_Accuracy: 0.6427
# Epoch 239/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 7.3736 - Accuracy: 0.6710 - val_loss: 7.3825 - val_Accuracy: 0.6427
# Epoch 240/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 7.3202 - Accuracy: 0.6717 - val_loss: 7.3222 - val_Accuracy: 0.6427
# Epoch 241/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 7.2623 - Accuracy: 0.6707 - val_loss: 7.2610 - val_Accuracy: 0.6427
# Epoch 242/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 7.2073 - Accuracy: 0.6714 - val_loss: 7.2522 - val_Accuracy: 0.6427
# Epoch 243/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 7.1548 - Accuracy: 0.6683 - val_loss: 7.1647 - val_Accuracy: 0.6427
# Epoch 244/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 7.0977 - Accuracy: 0.6727 - val_loss: 7.0926 - val_Accuracy: 0.6427
# Epoch 245/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 7.0438 - Accuracy: 0.6729 - val_loss: 7.0517 - val_Accuracy: 0.6427
# Epoch 246/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 6.9906 - Accuracy: 0.6735 - val_loss: 7.0080 - val_Accuracy: 0.6427
# Epoch 247/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 6.9375 - Accuracy: 0.6709 - val_loss: 6.9349 - val_Accuracy: 0.6427
# Epoch 248/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 6.8823 - Accuracy: 0.6745 - val_loss: 6.8773 - val_Accuracy: 0.6427
# Epoch 249/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 6.8357 - Accuracy: 0.6696 - val_loss: 6.8597 - val_Accuracy: 0.6427
# Epoch 250/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 6.7797 - Accuracy: 0.6734 - val_loss: 6.7875 - val_Accuracy: 0.6427
# Epoch 251/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 6.7267 - Accuracy: 0.6729 - val_loss: 6.7270 - val_Accuracy: 0.6427
# Epoch 252/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 6.6738 - Accuracy: 0.6719 - val_loss: 6.6765 - val_Accuracy: 0.6427
# Epoch 253/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 6.6227 - Accuracy: 0.6722 - val_loss: 6.6444 - val_Accuracy: 0.6427
# Epoch 254/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 6.5732 - Accuracy: 0.6718 - val_loss: 6.5797 - val_Accuracy: 0.6427
# Epoch 255/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 6.5207 - Accuracy: 0.6722 - val_loss: 6.5269 - val_Accuracy: 0.6427
# Epoch 256/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 6.4693 - Accuracy: 0.6734 - val_loss: 6.4833 - val_Accuracy: 0.6427
# Epoch 257/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 6.4203 - Accuracy: 0.6712 - val_loss: 6.4365 - val_Accuracy: 0.6427
# Epoch 258/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 6.3690 - Accuracy: 0.6723 - val_loss: 6.3843 - val_Accuracy: 0.6427
# Epoch 259/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 6.3207 - Accuracy: 0.6709 - val_loss: 6.3307 - val_Accuracy: 0.6427
# Epoch 260/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 6.2744 - Accuracy: 0.6713 - val_loss: 6.2831 - val_Accuracy: 0.6427
# Epoch 261/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 6.2240 - Accuracy: 0.6727 - val_loss: 6.2338 - val_Accuracy: 0.6427
# Epoch 262/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 6.1731 - Accuracy: 0.6728 - val_loss: 6.1918 - val_Accuracy: 0.6427
# Epoch 263/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 6.1236 - Accuracy: 0.6735 - val_loss: 6.1337 - val_Accuracy: 0.6427
# Epoch 264/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 6.0781 - Accuracy: 0.6734 - val_loss: 6.0960 - val_Accuracy: 0.6427
# Epoch 265/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 6.0283 - Accuracy: 0.6728 - val_loss: 6.0364 - val_Accuracy: 0.6427
# Epoch 266/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 5.9826 - Accuracy: 0.6719 - val_loss: 6.0009 - val_Accuracy: 0.6427
# Epoch 267/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 5.9327 - Accuracy: 0.6734 - val_loss: 5.9594 - val_Accuracy: 0.6427
# Epoch 268/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 5.8865 - Accuracy: 0.6722 - val_loss: 5.9168 - val_Accuracy: 0.6427
# Epoch 269/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 5.8402 - Accuracy: 0.6731 - val_loss: 5.8507 - val_Accuracy: 0.6427
# Epoch 270/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 5.7946 - Accuracy: 0.6719 - val_loss: 5.8028 - val_Accuracy: 0.6427
# Epoch 271/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 5.7467 - Accuracy: 0.6739 - val_loss: 5.7616 - val_Accuracy: 0.6427
# Epoch 272/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 5.7022 - Accuracy: 0.6734 - val_loss: 5.7185 - val_Accuracy: 0.6427
# Epoch 273/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 5.6585 - Accuracy: 0.6724 - val_loss: 5.6949 - val_Accuracy: 0.6427
# Epoch 274/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 5.6117 - Accuracy: 0.6721 - val_loss: 5.6329 - val_Accuracy: 0.6427
# Epoch 275/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 5.5668 - Accuracy: 0.6740 - val_loss: 5.5838 - val_Accuracy: 0.6427
# Epoch 276/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 5.5210 - Accuracy: 0.6737 - val_loss: 5.5292 - val_Accuracy: 0.6427
# Epoch 277/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 5.4765 - Accuracy: 0.6735 - val_loss: 5.4908 - val_Accuracy: 0.6427
# Epoch 278/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 5.4336 - Accuracy: 0.6732 - val_loss: 5.4498 - val_Accuracy: 0.6427
# Epoch 279/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 5.3900 - Accuracy: 0.6729 - val_loss: 5.4096 - val_Accuracy: 0.6427
# Epoch 280/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 5.3444 - Accuracy: 0.6729 - val_loss: 5.3680 - val_Accuracy: 0.6427
# Epoch 281/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 5.3031 - Accuracy: 0.6732 - val_loss: 5.3210 - val_Accuracy: 0.6427
# Epoch 282/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 5.2609 - Accuracy: 0.6724 - val_loss: 5.2780 - val_Accuracy: 0.6427
# Epoch 283/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 5.2167 - Accuracy: 0.6734 - val_loss: 5.2352 - val_Accuracy: 0.6427
# Epoch 284/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 5.1760 - Accuracy: 0.6724 - val_loss: 5.1865 - val_Accuracy: 0.6427
# Epoch 285/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 5.1325 - Accuracy: 0.6735 - val_loss: 5.1396 - val_Accuracy: 0.6427
# Epoch 286/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 5.0924 - Accuracy: 0.6724 - val_loss: 5.1008 - val_Accuracy: 0.6427
# Epoch 287/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 5.0484 - Accuracy: 0.6735 - val_loss: 5.0724 - val_Accuracy: 0.6427
# Epoch 288/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 5.0093 - Accuracy: 0.6723 - val_loss: 5.0432 - val_Accuracy: 0.6427
# Epoch 289/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 4.9683 - Accuracy: 0.6732 - val_loss: 4.9924 - val_Accuracy: 0.6427
# Epoch 290/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 4.9268 - Accuracy: 0.6737 - val_loss: 4.9511 - val_Accuracy: 0.6427
# Epoch 291/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 4.8874 - Accuracy: 0.6736 - val_loss: 4.9028 - val_Accuracy: 0.6427
# Epoch 292/1000
# ...
# Epoch 684/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6394 - Accuracy: 0.6735 - val_loss: 0.6614 - val_Accuracy: 0.6427
# Epoch 685/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6392 - Accuracy: 0.6735 - val_loss: 0.6614 - val_Accuracy: 0.6427
# Epoch 686/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6390 - Accuracy: 0.6735 - val_loss: 0.6611 - val_Accuracy: 0.6427
# Epoch 687/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6388 - Accuracy: 0.6735 - val_loss: 0.6610 - val_Accuracy: 0.6427
# Epoch 688/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6386 - Accuracy: 0.6735 - val_loss: 0.6607 - val_Accuracy: 0.6427
# Epoch 689/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6384 - Accuracy: 0.6735 - val_loss: 0.6606 - val_Accuracy: 0.6427
# Epoch 690/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 0.6383 - Accuracy: 0.6735 - val_loss: 0.6605 - val_Accuracy: 0.6427
# Epoch 691/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6381 - Accuracy: 0.6735 - val_loss: 0.6602 - val_Accuracy: 0.6427
# Epoch 692/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6380 - Accuracy: 0.6735 - val_loss: 0.6601 - val_Accuracy: 0.6427
# Epoch 693/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 0.6378 - Accuracy: 0.6735 - val_loss: 0.6599 - val_Accuracy: 0.6427
# Epoch 694/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 0.6376 - Accuracy: 0.6735 - val_loss: 0.6598 - val_Accuracy: 0.6427
# Epoch 695/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 0.6375 - Accuracy: 0.6735 - val_loss: 0.6597 - val_Accuracy: 0.6427
# Epoch 696/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 0.6374 - Accuracy: 0.6735 - val_loss: 0.6595 - val_Accuracy: 0.6427
# Epoch 697/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.6372 - Accuracy: 0.6735 - val_loss: 0.6594 - val_Accuracy: 0.6427
# Epoch 698/1000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.6371 - Accuracy: 0.6735 - val_loss: 0.6592 - val_Accuracy: 0.6427
# Epoch 699/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6369 - Accuracy: 0.6735 - val_loss: 0.6591 - val_Accuracy: 0.6427
# Epoch 700/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.6368 - Accuracy: 0.6735 - val_loss: 0.6590 - val_Accuracy: 0.6427
# Epoch 701/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6367 - Accuracy: 0.6735 - val_loss: 0.6588 - val_Accuracy: 0.6427
# Epoch 702/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6365 - Accuracy: 0.6735 - val_loss: 0.6586 - val_Accuracy: 0.6427
# Epoch 703/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6364 - Accuracy: 0.6735 - val_loss: 0.6586 - val_Accuracy: 0.6427
# Epoch 704/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6363 - Accuracy: 0.6735 - val_loss: 0.6585 - val_Accuracy: 0.6427
# Epoch 705/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6362 - Accuracy: 0.6735 - val_loss: 0.6584 - val_Accuracy: 0.6427
# Epoch 706/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6360 - Accuracy: 0.6735 - val_loss: 0.6582 - val_Accuracy: 0.6427
# Epoch 707/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6359 - Accuracy: 0.6735 - val_loss: 0.6580 - val_Accuracy: 0.6427
# Epoch 708/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6358 - Accuracy: 0.6735 - val_loss: 0.6581 - val_Accuracy: 0.6427
# Epoch 709/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 0.6357 - Accuracy: 0.6735 - val_loss: 0.6579 - val_Accuracy: 0.6427
# Epoch 710/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 0.6356 - Accuracy: 0.6735 - val_loss: 0.6578 - val_Accuracy: 0.6427
# Epoch 711/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6355 - Accuracy: 0.6735 - val_loss: 0.6576 - val_Accuracy: 0.6427
# Epoch 712/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6354 - Accuracy: 0.6735 - val_loss: 0.6576 - val_Accuracy: 0.6427
# Epoch 713/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6353 - Accuracy: 0.6735 - val_loss: 0.6575 - val_Accuracy: 0.6427
# Epoch 714/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6352 - Accuracy: 0.6735 - val_loss: 0.6573 - val_Accuracy: 0.6427
# Epoch 715/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6351 - Accuracy: 0.6735 - val_loss: 0.6573 - val_Accuracy: 0.6427
# Epoch 716/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6350 - Accuracy: 0.6735 - val_loss: 0.6572 - val_Accuracy: 0.6427
# Epoch 717/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6349 - Accuracy: 0.6735 - val_loss: 0.6571 - val_Accuracy: 0.6427
# Epoch 718/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6348 - Accuracy: 0.6735 - val_loss: 0.6571 - val_Accuracy: 0.6427
# Epoch 719/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6348 - Accuracy: 0.6735 - val_loss: 0.6570 - val_Accuracy: 0.6427
# Epoch 720/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6347 - Accuracy: 0.6735 - val_loss: 0.6568 - val_Accuracy: 0.6427
# Epoch 721/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6346 - Accuracy: 0.6735 - val_loss: 0.6568 - val_Accuracy: 0.6427
# Epoch 722/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 0.6345 - Accuracy: 0.6735 - val_loss: 0.6567 - val_Accuracy: 0.6427
# Epoch 723/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6344 - Accuracy: 0.6735 - val_loss: 0.6566 - val_Accuracy: 0.6427
# Epoch 724/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6344 - Accuracy: 0.6735 - val_loss: 0.6567 - val_Accuracy: 0.6427
# Epoch 725/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6343 - Accuracy: 0.6735 - val_loss: 0.6565 - val_Accuracy: 0.6427
# Epoch 726/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.6342 - Accuracy: 0.6735 - val_loss: 0.6565 - val_Accuracy: 0.6427
# Epoch 727/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.6342 - Accuracy: 0.6735 - val_loss: 0.6564 - val_Accuracy: 0.6427
# Epoch 728/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6341 - Accuracy: 0.6735 - val_loss: 0.6563 - val_Accuracy: 0.6427
# Epoch 729/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6340 - Accuracy: 0.6735 - val_loss: 0.6562 - val_Accuracy: 0.6427
# Epoch 730/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6340 - Accuracy: 0.6735 - val_loss: 0.6562 - val_Accuracy: 0.6427
# Epoch 731/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6339 - Accuracy: 0.6735 - val_loss: 0.6561 - val_Accuracy: 0.6427
# Epoch 732/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6339 - Accuracy: 0.6735 - val_loss: 0.6560 - val_Accuracy: 0.6427
# Epoch 733/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6338 - Accuracy: 0.6735 - val_loss: 0.6561 - val_Accuracy: 0.6427
# Epoch 734/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6337 - Accuracy: 0.6735 - val_loss: 0.6559 - val_Accuracy: 0.6427
# Epoch 735/1000
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6337 - Accuracy: 0.6735 - val_loss: 0.6558 - val_Accuracy: 0.6427
# Epoch 736/1000
# 10/10 [==============================] - 1s 54ms/step - loss: 0.6336 - Accuracy: 0.6735 - val_loss: 0.6558 - val_Accuracy: 0.6427
# Epoch 737/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.6336 - Accuracy: 0.6735 - val_loss: 0.6558 - val_Accuracy: 0.6427
# Epoch 738/1000
# 10/10 [==============================] - 1s 58ms/step - loss: 0.6335 - Accuracy: 0.6735 - val_loss: 0.6558 - val_Accuracy: 0.6427
# Epoch 739/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6335 - Accuracy: 0.6735 - val_loss: 0.6557 - val_Accuracy: 0.6427
# Epoch 740/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6334 - Accuracy: 0.6735 - val_loss: 0.6556 - val_Accuracy: 0.6427
# Epoch 741/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6334 - Accuracy: 0.6735 - val_loss: 0.6556 - val_Accuracy: 0.6427
# Epoch 742/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6333 - Accuracy: 0.6735 - val_loss: 0.6556 - val_Accuracy: 0.6427
# Epoch 743/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6333 - Accuracy: 0.6735 - val_loss: 0.6555 - val_Accuracy: 0.6427
# Epoch 744/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 0.6332 - Accuracy: 0.6735 - val_loss: 0.6554 - val_Accuracy: 0.6427
# Epoch 745/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.6332 - Accuracy: 0.6735 - val_loss: 0.6555 - val_Accuracy: 0.6427
# Epoch 746/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6332 - Accuracy: 0.6735 - val_loss: 0.6554 - val_Accuracy: 0.6427
# Epoch 747/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6331 - Accuracy: 0.6735 - val_loss: 0.6553 - val_Accuracy: 0.6427
# Epoch 748/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6331 - Accuracy: 0.6735 - val_loss: 0.6553 - val_Accuracy: 0.6427
# Epoch 749/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.6330 - Accuracy: 0.6735 - val_loss: 0.6553 - val_Accuracy: 0.6427
# Epoch 750/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6330 - Accuracy: 0.6735 - val_loss: 0.6552 - val_Accuracy: 0.6427
# Epoch 751/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6330 - Accuracy: 0.6735 - val_loss: 0.6551 - val_Accuracy: 0.6427
# Epoch 752/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 0.6329 - Accuracy: 0.6735 - val_loss: 0.6552 - val_Accuracy: 0.6427
# Epoch 753/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6329 - Accuracy: 0.6735 - val_loss: 0.6550 - val_Accuracy: 0.6427
# Epoch 754/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6329 - Accuracy: 0.6735 - val_loss: 0.6551 - val_Accuracy: 0.6427
# Epoch 755/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6328 - Accuracy: 0.6735 - val_loss: 0.6551 - val_Accuracy: 0.6427
# Epoch 756/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6328 - Accuracy: 0.6735 - val_loss: 0.6551 - val_Accuracy: 0.6427
# Epoch 757/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6328 - Accuracy: 0.6735 - val_loss: 0.6549 - val_Accuracy: 0.6427
# Epoch 758/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6327 - Accuracy: 0.6735 - val_loss: 0.6550 - val_Accuracy: 0.6427
# Epoch 759/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.6327 - Accuracy: 0.6735 - val_loss: 0.6550 - val_Accuracy: 0.6427
# Epoch 760/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6327 - Accuracy: 0.6735 - val_loss: 0.6549 - val_Accuracy: 0.6427
# Epoch 761/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6327 - Accuracy: 0.6735 - val_loss: 0.6549 - val_Accuracy: 0.6427
# Epoch 762/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6326 - Accuracy: 0.6735 - val_loss: 0.6548 - val_Accuracy: 0.6427
# Epoch 763/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.6326 - Accuracy: 0.6735 - val_loss: 0.6549 - val_Accuracy: 0.6427
# Epoch 764/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6326 - Accuracy: 0.6735 - val_loss: 0.6549 - val_Accuracy: 0.6427
# Epoch 765/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6326 - Accuracy: 0.6735 - val_loss: 0.6548 - val_Accuracy: 0.6427
# Epoch 766/1000
# 10/10 [==============================] - 0s 31ms/step - loss: 0.6325 - Accuracy: 0.6735 - val_loss: 0.6548 - val_Accuracy: 0.6427
# Epoch 767/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6325 - Accuracy: 0.6735 - val_loss: 0.6547 - val_Accuracy: 0.6427
# Epoch 768/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6325 - Accuracy: 0.6735 - val_loss: 0.6546 - val_Accuracy: 0.6427
# Epoch 769/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6325 - Accuracy: 0.6735 - val_loss: 0.6548 - val_Accuracy: 0.6427
# Epoch 770/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6325 - Accuracy: 0.6735 - val_loss: 0.6546 - val_Accuracy: 0.6427
# Epoch 771/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6324 - Accuracy: 0.6735 - val_loss: 0.6547 - val_Accuracy: 0.6427
# Epoch 772/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6324 - Accuracy: 0.6735 - val_loss: 0.6547 - val_Accuracy: 0.6427
# Epoch 773/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6324 - Accuracy: 0.6735 - val_loss: 0.6546 - val_Accuracy: 0.6427
# Epoch 774/1000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.6323 - Accuracy: 0.6735 - val_loss: 0.6545 - val_Accuracy: 0.6427
# Epoch 775/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 0.6324 - Accuracy: 0.6735 - val_loss: 0.6546 - val_Accuracy: 0.6427
# Epoch 776/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6323 - Accuracy: 0.6735 - val_loss: 0.6545 - val_Accuracy: 0.6427
# Epoch 777/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6323 - Accuracy: 0.6735 - val_loss: 0.6545 - val_Accuracy: 0.6427
# Epoch 778/1000
# 10/10 [==============================] - 0s 39ms/step - loss: 0.6323 - Accuracy: 0.6735 - val_loss: 0.6545 - val_Accuracy: 0.6427
# Epoch 779/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6323 - Accuracy: 0.6735 - val_loss: 0.6546 - val_Accuracy: 0.6427
# Epoch 780/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 0.6323 - Accuracy: 0.6735 - val_loss: 0.6545 - val_Accuracy: 0.6427
# Epoch 781/1000
# 10/10 [==============================] - 0s 32ms/step - loss: 0.6323 - Accuracy: 0.6735 - val_loss: 0.6547 - val_Accuracy: 0.6427
# Epoch 782/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.6322 - Accuracy: 0.6735 - val_loss: 0.6543 - val_Accuracy: 0.6427
# Epoch 783/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6322 - Accuracy: 0.6735 - val_loss: 0.6545 - val_Accuracy: 0.6427
# Epoch 784/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6322 - Accuracy: 0.6735 - val_loss: 0.6545 - val_Accuracy: 0.6427
# Epoch 785/1000
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6322 - Accuracy: 0.6735 - val_loss: 0.6544 - val_Accuracy: 0.6427
# Epoch 786/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6322 - Accuracy: 0.6735 - val_loss: 0.6545 - val_Accuracy: 0.6427
# Epoch 787/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.6322 - Accuracy: 0.6735 - val_loss: 0.6544 - val_Accuracy: 0.6427
# Epoch 788/1000
# 10/10 [==============================] - 0s 35ms/step - loss: 0.6321 - Accuracy: 0.6735 - val_loss: 0.6545 - val_Accuracy: 0.6427
# Epoch 789/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 0.6321 - Accuracy: 0.6735 - val_loss: 0.6543 - val_Accuracy: 0.6427
# Epoch 790/1000
# 10/10 [==============================] - 0s 38ms/step - loss: 0.6321 - Accuracy: 0.6735 - val_loss: 0.6544 - val_Accuracy: 0.6427
# Epoch 791/1000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.6321 - Accuracy: 0.6735 - val_loss: 0.6543 - val_Accuracy: 0.6427
# Epoch 792/1000
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6321 - Accuracy: 0.6735Restoring model weights from the end of the best epoch: 782.
# 10/10 [==============================] - 0s 40ms/step - loss: 0.6321 - Accuracy: 0.6735 - val_loss: 0.6543 - val_Accuracy: 0.6427
# Epoch 792: early stopping

# %% [markdown]
# ### Evaluate Model

# %%
yhat = edge_model.predict(full_edge_dataset)
yhat_df = edge_full_adj.copy().set_index(['source','target'])
yhat_df['conf_game_yhat'] = yhat.round(0)
yhat_df = yhat_df.loc[yhat_df.index.isin(
    edge_test.set_index(['source','target']).index)]
yhat_df['loss'] = abs(yhat_df['conference_game'] - yhat_df['conf_game_yhat'])
loss = yhat_df['loss'].mean()
print("edge accuracy:",1 - loss)
# Out:
# 1/1 [==============================] - 16s 16s/step
# edge accuracy: 0.563953488372093

# %% [markdown]
# ##### Again, we successfully trained a model and will worry about accuracy when we get to model tunning
# # Troubleshooting Techniques
# ### Create Graph Spec

# %%
graph_spec = tfgnn.GraphTensorSpec.from_piece_specs(
    context_spec = tfgnn.ContextSpec.from_field_specs(
        features_spec ={
            #Added as an example for context problems
            #"conf_rank": tf.TensorSpec(shape=(None,1), dtype=tf.float32),
        }),
    node_sets_spec={
        'schools':
            tfgnn.NodeSetSpec.from_field_specs(
                features_spec={
                    'Latitude': tf.TensorSpec((None, 1), tf.float32),
                    'Longitude': tf.TensorSpec((None, 1), tf.float32),
                    'Rank': tf.TensorSpec((None, 1), tf.int32),
                    'Wins': tf.TensorSpec((None, 1), tf.int32),
                    'Conf_wins': tf.TensorSpec((None, 1), tf.int32),
                    'conference': tf.TensorSpec((None, 12), tf.int32)
                },
                sizes_spec=tf.TensorSpec((1,), tf.int32))
    },
    edge_sets_spec={
        'games':
            tfgnn.EdgeSetSpec.from_field_specs(
                features_spec={
                    'name_sim_score': tf.TensorSpec((None, 1), tf.float32),
                    'euclidean_dist': tf.TensorSpec((None, 1), tf.float32),
                    'conference_game': tf.TensorSpec((None, 1), tf.int32)
                },
                sizes_spec=tf.TensorSpec((1,), tf.int32),
                adjacency_spec=tfgnn.AdjacencySpec.from_incident_node_sets(
                    'schools', 'schools'))
    })

# %% [markdown]
# ### Test Graph Spec

# %%
graph_spec.is_compatible_with(full_tensor)
# Out:
# True

# %% [markdown]
# ### Build Model From Graph Spec

# %%
input_graph = tf.keras.layers.Input(type_spec=graph_spec)

graph = tfgnn.keras.layers.MapFeatures(
    node_sets_fn=set_initial_node_state,
    edge_sets_fn=set_initial_edge_state
)(input_graph)

graph_updates = 3
for i in range(graph_updates):
    graph = tfgnn.keras.layers.GraphUpdate(
        edge_sets = {'games': tfgnn.keras.layers.EdgeSetUpdate(
            next_state = tfgnn.keras.layers.NextStateFromConcat(
                dense_layer(64,activation='relu')))},
        node_sets = {
            'schools': tfgnn.keras.layers.NodeSetUpdate({
                'games': tfgnn.keras.layers.SimpleConv(
                    message_fn = dense_layer(32),
                    reduce_type="sum",
                    receiver_tag=tfgnn.TARGET)},
                tfgnn.keras.layers.NextStateFromConcat(
                    dense_layer(64)))})(graph)

    logits = tf.keras.layers.Dense(1,activation='sigmoid')(graph.edge_sets["games"][tfgnn.HIDDEN_STATE])

test_model = tf.keras.Model(input_graph, logits)

# %% [markdown]
# ### Create Random Graph From Graph Spec

# %%
random_graph = tfgnn.random_graph_tensor(graph_spec)
print("Nodes:",random_graph.node_sets['schools'].features)
print("Edges:",random_graph.edge_sets['games'].features)
print("Context:",random_graph.context.features)
# Out:
# Nodes: {'Latitude': <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
# array([[0.0190109 ],
#        [0.69601953],
#        [0.7011608 ],
#        [0.53219724],
#        [0.39926624]], dtype=float32)>, 'Longitude': <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
# array([[0.92046523],
#        [0.29431486],
#        [0.93218577],
#        [0.72809124],
#        [0.8630272 ]], dtype=float32)>, 'Rank': <tf.Tensor: shape=(5, 1), dtype=int32, numpy=
# array([[18],
#        [44],
#        [37],
#        [27],
#        [13]], dtype=int32)>, 'Wins': <tf.Tensor: shape=(5, 1), dtype=int32, numpy=
# array([[68],
#        [91],
#        [15],
#        [65],
#        [22]], dtype=int32)>, 'Conf_wins': <tf.Tensor: shape=(5, 1), dtype=int32, numpy=
# array([[82],
#        [71],
#        [34],
#        [50],
#        [73]], dtype=int32)>, 'conference': <tf.Tensor: shape=(5, 12), dtype=int32, numpy=
# array([[67, 79, 51, 28, 96, 63, 68, 41, 76, 87, 68, 25],
#        [93, 37, 45, 11, 23, 17, 31, 33, 26, 65, 84, 69],
#        [71, 61, 89, 83, 96, 74, 84, 61, 84, 61, 23, 80],
#        [88, 26, 66, 42, 50, 77, 16, 18, 18, 94, 72, 62],
#        [24, 54, 92, 98, 70, 56, 75, 29, 98, 87, 91, 51]], dtype=int32)>}
# Edges: {'name_sim_score': <tf.Tensor: shape=(20, 1), dtype=float32, numpy=
# array([[0.90426874],
#        [0.43417966],
#        [0.6806396 ],
#        [0.46925128],
#        [0.76089597],
#        [0.15425742],
#        [0.07822776],
#        [0.5629443 ],
#        [0.747947  ],
#        [0.41803408],
#        [0.92021966],
#        [0.6744064 ],
#        [0.10340357],
#        [0.4944644 ],
#        [0.97293866],
#        [0.1259439 ],
#        [0.95263934],
#        [0.6589004 ],
#        [0.12905097],
#        [0.94509923]], dtype=float32)>, 'euclidean_dist': <tf.Tensor: shape=(20, 1), dtype=float32, numpy=
# array([[0.18412423],
#        [0.38712478],
#        [0.3230363 ],
#        [0.13742626],
#        [0.2833656 ],
#        [0.43119752],
#        [0.95191574],
#        [0.30705988],
#        [0.12997234],
#        [0.799325  ],
#        [0.00168753],
#        [0.26221454],
#        [0.30033255],
#        [0.41463292],
#        [0.4102062 ],
#        [0.24359858],
#        [0.17319226],
#        [0.10956955],
#        [0.00625181],
#        [0.04492366]], dtype=float32)>, 'conference_game': <tf.Tensor: shape=(20, 1), dtype=int32, numpy=
# array([[37],
#        [83],
#        [94],
#        [98],
#        [49],
#        [76],
#        [87],
#        [49],
#        [80],
#        [88],
#        [73],
#        [76],
#        [84],
#        [68],
#        [36],
#        [11],
#        [57],
#        [56],
#        [70],
#        [91]], dtype=int32)>}
# Context: {}

# %% [markdown]
# # Parameter Tuning
# ### Build Class

# %%
class GCNN:
    def __init__(self,params):
        self.params = params
        
    def set_initial_node_state(self, node_set, node_set_name):
        features = [
            tf.keras.layers.Dense(self.params['feature_dim'],activation="relu")(node_set['Latitude']),
            tf.keras.layers.Dense(self.params['feature_dim'],activation="relu")(node_set['Longitude']),
            tf.keras.layers.Dense(self.params['feature_dim'],activation="relu")(node_set['Rank']),
            tf.keras.layers.Dense(self.params['feature_dim'],activation="relu")(node_set['Wins']),
            tf.keras.layers.Dense(self.params['feature_dim'],activation="relu")(node_set['Conf_wins'])
        ]
        return tf.keras.layers.Concatenate()(features)

    def set_initial_edge_state(self, edge_set, edge_set_name):
        features = [
            tf.keras.layers.Dense(self.params['feature_dim'],activation="relu")(edge_set['name_sim_score']),
            tf.keras.layers.Dense(self.params['feature_dim'],activation="relu")(edge_set['euclidean_dist'])
        ]
        return tf.keras.layers.Concatenate()(features)

    def dense_layer(self,units=64):
        regularizer = tf.keras.regularizers.l2(self.params['l2_reg'])
        return tf.keras.Sequential([
            tf.keras.layers.Dense(units,
                                  kernel_regularizer=regularizer,
                                  bias_regularizer=regularizer,
                                  activation='relu'),
            tf.keras.layers.Dropout(self.params['dropout'])])

    def build_model(self):
        input_graph = tf.keras.layers.Input(type_spec=self.params['trainset'].element_spec[0])
        graph = tfgnn.keras.layers.MapFeatures(
            node_sets_fn=self.set_initial_node_state,
            edge_sets_fn=self.set_initial_edge_state
        )(input_graph)
        
        if self.params['loss']=='categorical_crossentropy':
            for i in range(self.params['graph_updates']):
                graph = tfgnn.keras.layers.GraphUpdate(
                    node_sets = {
                        'schools': tfgnn.keras.layers.NodeSetUpdate({
                            'games': tfgnn.keras.layers.SimpleConv(
                                message_fn = self.dense_layer(self.params['message_dim']),
                                reduce_type="sum",
                                receiver_tag=tfgnn.TARGET)},
                            tfgnn.keras.layers.NextStateFromConcat(
                                self.dense_layer(self.params['next_state_dim'])))})(graph)
            logits = tf.keras.layers.Dense(12,activation='softmax')(graph.node_sets["schools"][tfgnn.HIDDEN_STATE])
        else:
            for i in range(self.params['graph_updates']):
                graph = tfgnn.keras.layers.GraphUpdate(
                    edge_sets = {'games': tfgnn.keras.layers.EdgeSetUpdate(
                        next_state = tfgnn.keras.layers.NextStateFromConcat(
                            self.dense_layer(self.params['next_state_dim'])))},
                    node_sets = {
                        'schools': tfgnn.keras.layers.NodeSetUpdate({
                            'games': tfgnn.keras.layers.SimpleConv(
                                message_fn = self.dense_layer(self.params['message_dim']),
                                reduce_type="sum",
                                receiver_tag=tfgnn.TARGET)},
                            tfgnn.keras.layers.NextStateFromConcat(
                                self.dense_layer(self.params['next_state_dim'])))})(graph)
            logits = tf.keras.layers.Dense(1,activation='sigmoid')(graph.edge_sets["games"][tfgnn.HIDDEN_STATE])
        return tf.keras.Model(input_graph, logits)
        
    def train_model(self,trial=True):
        model = self.build_model()
        
        model.compile(tf.keras.optimizers.Adam(learning_rate=self.params['learning_rate']),
                      loss=self.params['loss'],
                      metrics=['Accuracy'])
        
        callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                      mode='min',
                                                      verbose=1,
                                                      patience=self.params['patience'],
                                                      restore_best_weights=True)]
        
        model.fit(self.params['trainset'].repeat(),
                  validation_data=self.params['full_dataset'],
                  steps_per_epoch=self.params['steps_per_epoch'],
                  epochs=self.params['epochs'],
                  verbose=0,
                  callbacks = callbacks)
        
        loss = self.evaluate_model(model,trial=trial)
            
        if trial == True:
            sys.stdout.flush()
            hypt_params = {
                'graph_updates':self.params['graph_updates'],
                'feature_dim':self.params['feature_dim'],
                'next_state_dim':self.params['next_state_dim'],
                'message_dim':self.params['message_dim'],
                'l2_reg':self.params['l2_reg'],
                'dropout':self.params['dropout'],
                'learning_rate':self.params['learning_rate']}
            print(hypt_params,'loss:',loss)
            return {'loss': loss, 'status': STATUS_OK}
        else:
            print('loss:',loss)
            return model
        
    def evaluate_model(self,model,trial=True):
        if self.params['loss'] == 'categorical_crossentropy':
            yhat = model.predict(full_node_dataset)
            yhat_df = node_full_adj.set_index('school').iloc[:,-12:].copy()
            yhat_df.iloc[:,:] = yhat
            yhat_df = yhat_df.apply(lambda x: x == x.max(), axis=1).astype(int)
            yhat_df = yhat_df.dot(yhat_df.columns).to_frame().rename(columns={0:"conf_yhat"})
            yhat_df = yhat_df['conf_yhat'].str.replace('conf_', '').astype(int).to_frame()
            yhat_df['conf_actual'] = node_full_adj.set_index('school')['conference']
            yhat_df['Accuracy'] = yhat_df['conf_yhat']==yhat_df['conf_actual']
            if trial == False:
                print("full dataset accuracy:",yhat_df['Accuracy'].mean())
                print('Conference Actual Full Dataset')
                G_yhat = G.copy()
                draw_map(G_yhat,edge_df,node_df,nodes=list(yhat_df.index),size=[8,6])
                plt.show()
                print('Predicted Conference Full Dataset')
                nx.set_node_attributes(G_yhat, dict(zip(yhat_df.index,yhat_df.conf_yhat)), 'value')
                draw_map(G_yhat,edge_df,node_df,nodes=list(yhat_df.index),size=[8,6])
                plt.show()

            yhat_df = yhat_df.loc[yhat_df.index.isin(node_test.index)]
            loss = 1 - yhat_df['Accuracy'].mean()
            if trial==False:
                print('Conference Actual Holdout Dataset')
                G_yhat = G.copy()
                draw_map(G_yhat,edge_df,node_df,nodes=list(yhat_df.index),size=[8,6])
                plt.show()
                print('Predicted Conference Holdout Dataset')
                nx.set_node_attributes(G_yhat, dict(zip(yhat_df.index,yhat_df.conf_yhat)), 'value')
                draw_map(G_yhat,edge_df,node_df,nodes=list(yhat_df.index),size=[8,6])
                plt.show()
        else:
            yhat = model.predict(full_edge_dataset)
            yhat_df = edge_full_adj.copy().set_index(['source','target'])
            yhat_df['conf_game_yhat'] = yhat.round(0)
            yhat_df = yhat_df.loc[yhat_df.index.isin(
                edge_test.set_index(['source','target']).index)]
            yhat_df['loss'] = abs(yhat_df['conference_game'] - yhat_df['conf_game_yhat'])
            loss = yhat_df['loss'].mean()
        return loss

# %% [markdown]
# ### Tune Node Model
# ##### Due to colabs limited resources, I will do a short trial here to show how it works. I would recommend doing 70-100 max_evals

# %%
params = {
    ### Tuning parameters ###
    'graph_updates': hp.choice('graph_updates',[2,3,4]),
    'feature_dim': hp.choice('feature_dim',[16,32,64,128]),
    'message_dim': hp.choice('message_dim',[16,32,64,128]),
    'next_state_dim': hp.choice('next_state_dim',[16,32,64,128]),
    'l2_reg': hp.uniform('l2_reg',0.0,0.3),
    'dropout': hp.choice('dropout',[0,0.125,0.25,0.375,0.5]),
    'learning_rate': hp.uniform('learning_rate',0.0,0.1),
    
    ### Static parameters ###
    'loss': 'categorical_crossentropy',
    'epochs': 1000,
    'steps_per_epoch':10, ### This could also be a tuned parameter
    'patience':10,
    'trainset':train_node_dataset,
    'full_dataset':full_node_dataset
}

def tune_model(params):
    return GCNN(params).train_model()

best_node = fmin(tune_model, params, algo=tpe.suggest,
                 max_evals=2, trials=Trials())
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s, best loss: ?]
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_2/graph_update_7/node_set_update_7/simple_conv_7/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_2/graph_update_7/node_set_update_7/simple_conv_7/Reshape_1:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_2/graph_update_7/node_set_update_7/simple_conv_7/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_2/graph_update_7/node_set_update_7/simple_conv_7/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_2/graph_update_7/node_set_update_7/simple_conv_7/Reshape_3:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_2/graph_update_7/node_set_update_7/simple_conv_7/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_2/graph_update_6/node_set_update_6/simple_conv_6/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_2/graph_update_6/node_set_update_6/simple_conv_6/Reshape_1:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_2/graph_update_6/node_set_update_6/simple_conv_6/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_2/graph_update_6/node_set_update_6/simple_conv_6/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_2/graph_update_6/node_set_update_6/simple_conv_6/Reshape_3:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_2/graph_update_6/node_set_update_6/simple_conv_6/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/kernel:0', 'dense_5/bias:0', 'dense_6/kernel:0', 'dense_6/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/kernel:0', 'dense_5/bias:0', 'dense_6/kernel:0', 'dense_6/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Restoring model weights from the end of the best epoch: 183.
#
# Epoch 193: early stopping
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 245ms/step
#
# {'graph_updates': 2, 'feature_dim': 32, 'next_state_dim': 64, 'message_dim': 64, 'l2_reg': 0.20607069970357286, 'dropout': 0, 'learning_rate': 0.07801349331608774}
# loss:
# 1.0
#  50%|█████     | 1/2 [00:49<00:49, 49.61s/it, best loss: 1.0]
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_3/graph_update_9/node_set_update_9/simple_conv_9/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_3/graph_update_9/node_set_update_9/simple_conv_9/Reshape_1:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_3/graph_update_9/node_set_update_9/simple_conv_9/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_3/graph_update_9/node_set_update_9/simple_conv_9/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_3/graph_update_9/node_set_update_9/simple_conv_9/Reshape_3:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_3/graph_update_9/node_set_update_9/simple_conv_9/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_3/graph_update_8/node_set_update_8/simple_conv_8/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_3/graph_update_8/node_set_update_8/simple_conv_8/Reshape_1:0", shape=(None, 320), dtype=float32), dense_shape=Tensor("gradient_tape/model_3/graph_update_8/node_set_update_8/simple_conv_8/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_3/graph_update_8/node_set_update_8/simple_conv_8/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_3/graph_update_8/node_set_update_8/simple_conv_8/Reshape_3:0", shape=(None, 320), dtype=float32), dense_shape=Tensor("gradient_tape/model_3/graph_update_8/node_set_update_8/simple_conv_8/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/kernel:0', 'dense_5/bias:0', 'dense_6/kernel:0', 'dense_6/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/kernel:0', 'dense_5/bias:0', 'dense_6/kernel:0', 'dense_6/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Restoring model weights from the end of the best epoch: 69.
#
# Epoch 79: early stopping
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 19s 19s/step
#
# {'graph_updates': 2, 'feature_dim': 64, 'next_state_dim': 64, 'message_dim': 64, 'l2_reg': 0.18812445292234972, 'dropout': 0.375, 'learning_rate': 0.03612839213819885}
# loss:
# 0.7222222222222222
# 100%|██████████| 2/2 [01:33<00:00, 46.64s/it, best loss: 0.7222222222222222]

# %% [markdown]
# ### Train Model
# ##### Best parameters from hyperopt run on my personal computer

# %%
top_params = {
    'graph_updates': 2,
    'feature_dim': 32,
    'next_state_dim': 64,
    'message_dim': 64,
    'l2_reg': 0.24,
    'dropout': 0.25,
    'learning_rate': 0.003
}

node_params = params
for param, value in top_params.items():
    node_params[param] = value

node_model = GCNN(node_params).train_model(trial=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_13/graph_update_33/node_set_update_33/simple_conv_33/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_13/graph_update_33/node_set_update_33/simple_conv_33/Reshape_1:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_13/graph_update_33/node_set_update_33/simple_conv_33/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_13/graph_update_33/node_set_update_33/simple_conv_33/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_13/graph_update_33/node_set_update_33/simple_conv_33/Reshape_3:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_13/graph_update_33/node_set_update_33/simple_conv_33/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_13/graph_update_32/node_set_update_32/simple_conv_32/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_13/graph_update_32/node_set_update_32/simple_conv_32/Reshape_1:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_13/graph_update_32/node_set_update_32/simple_conv_32/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_13/graph_update_32/node_set_update_32/simple_conv_32/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_13/graph_update_32/node_set_update_32/simple_conv_32/Reshape_3:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_13/graph_update_32/node_set_update_32/simple_conv_32/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/kernel:0', 'dense_5/bias:0', 'dense_6/kernel:0', 'dense_6/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/kernel:0', 'dense_5/bias:0', 'dense_6/kernel:0', 'dense_6/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Restoring model weights from the end of the best epoch: 151.
# Epoch 161: early stopping
# 1/1 [==============================] - 0s 279ms/step
# full dataset accuracy: 0.8782608695652174
# Conference Actual Full Dataset
# Predicted Conference Full Dataset
# Conference Actual Holdout Dataset
# Predicted Conference Holdout Dataset
# loss: 0.33333333333333337

# %% [markdown]
# ### Tune Edge Model
# ##### Again, doing a limited trial due to colab resources

# %%
params['loss'] = 'binary_crossentropy'
params['trainset'] = train_edge_dataset
params['full_dataset'] = full_edge_dataset

best_edge = fmin(tune_model, params, algo=tpe.suggest,
                 max_evals=2, trials=Trials())
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s, best loss: ?]
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("Adam/gradients/concat_1:0", shape=(None,), dtype=int32), values=Tensor("Adam/gradients/concat:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_17/graph_update_41/edge_set_update_7/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_17/graph_update_40/edge_set_update_6/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_17/graph_update_40/edge_set_update_6/Reshape:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_17/graph_update_40/edge_set_update_6/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_17/graph_update_40/edge_set_update_6/Reshape_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_17/graph_update_40/edge_set_update_6/Reshape_2:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_17/graph_update_40/edge_set_update_6/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_17/graph_update_40/node_set_update_40/simple_conv_40/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_17/graph_update_40/node_set_update_40/simple_conv_40/Reshape_1:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_17/graph_update_40/node_set_update_40/simple_conv_40/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_17/graph_update_40/node_set_update_40/simple_conv_40/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_17/graph_update_40/node_set_update_40/simple_conv_40/Reshape_3:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_17/graph_update_40/node_set_update_40/simple_conv_40/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# Restoring model weights from the end of the best epoch: 80.
#
# Epoch 90: early stopping
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 1s 756ms/step
#
# {'graph_updates': 2, 'feature_dim': 32, 'next_state_dim': 64, 'message_dim': 64, 'l2_reg': 0.24, 'dropout': 0.25, 'learning_rate': 0.003}
# loss:
# 0.14534883720930233
#  50%|█████     | 1/2 [00:34<00:34, 34.23s/it, best loss: 0.14534883720930233]
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("Adam/gradients/concat_1:0", shape=(None,), dtype=int32), values=Tensor("Adam/gradients/concat:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_18/graph_update_43/edge_set_update_9/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_18/graph_update_42/edge_set_update_8/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_18/graph_update_42/edge_set_update_8/Reshape:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_18/graph_update_42/edge_set_update_8/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_18/graph_update_42/edge_set_update_8/Reshape_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_18/graph_update_42/edge_set_update_8/Reshape_2:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_18/graph_update_42/edge_set_update_8/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_18/graph_update_42/node_set_update_42/simple_conv_42/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_18/graph_update_42/node_set_update_42/simple_conv_42/Reshape_1:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_18/graph_update_42/node_set_update_42/simple_conv_42/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_18/graph_update_42/node_set_update_42/simple_conv_42/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_18/graph_update_42/node_set_update_42/simple_conv_42/Reshape_3:0", shape=(None, 160), dtype=float32), dense_shape=Tensor("gradient_tape/model_18/graph_update_42/node_set_update_42/simple_conv_42/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# Restoring model weights from the end of the best epoch: 105.
#
# Epoch 115: early stopping
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 11s 11s/step
#
# {'graph_updates': 2, 'feature_dim': 32, 'next_state_dim': 64, 'message_dim': 64, 'l2_reg': 0.24, 'dropout': 0.25, 'learning_rate': 0.003}
# loss:
# 0.13372093023255813
# 100%|██████████| 2/2 [01:18<00:00, 39.14s/it, best loss: 0.13372093023255813]

# %% [markdown]
# ### Train Model
# ##### Best parameters from hyperopt run on my personal computer

# %%
### Perameters from my hyperopt run ###
best_edge = {
    'graph_updates': 4,
    'feature_dim': 64,
    'next_state_dim': 32,
    'message_dim': 128,
    'l2_reg': 0.095,
    'dropout': 0,
    'learning_rate': 0.0025
}

edge_params = params
for param, value in best_edge.items():
    edge_params[param] = value
    
edge_model = GCNN(edge_params).train_model(trial=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("Adam/gradients/concat_1:0", shape=(None,), dtype=int32), values=Tensor("Adam/gradients/concat:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_61/edge_set_update_14/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_60/edge_set_update_13/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_60/edge_set_update_13/Reshape:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_60/edge_set_update_13/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_60/edge_set_update_13/Reshape_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_60/edge_set_update_13/Reshape_2:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_60/edge_set_update_13/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_60/node_set_update_60/simple_conv_60/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_60/node_set_update_60/simple_conv_60/Reshape_1:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_60/node_set_update_60/simple_conv_60/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_60/node_set_update_60/simple_conv_60/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_60/node_set_update_60/simple_conv_60/Reshape_3:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_60/node_set_update_60/simple_conv_60/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_59/edge_set_update_12/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_59/edge_set_update_12/Reshape:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_59/edge_set_update_12/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_59/edge_set_update_12/Reshape_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_59/edge_set_update_12/Reshape_2:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_59/edge_set_update_12/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_59/node_set_update_59/simple_conv_59/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_59/node_set_update_59/simple_conv_59/Reshape_1:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_59/node_set_update_59/simple_conv_59/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_59/node_set_update_59/simple_conv_59/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_59/node_set_update_59/simple_conv_59/Reshape_3:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_59/node_set_update_59/simple_conv_59/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_58/edge_set_update_11/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_58/edge_set_update_11/Reshape:0", shape=(None, 320), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_58/edge_set_update_11/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_58/edge_set_update_11/Reshape_3:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_58/edge_set_update_11/Reshape_2:0", shape=(None, 320), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_58/edge_set_update_11/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_58/node_set_update_58/simple_conv_58/Reshape_2:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_58/node_set_update_58/simple_conv_58/Reshape_1:0", shape=(None, 320), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_58/node_set_update_58/simple_conv_58/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/model_28/graph_update_58/node_set_update_58/simple_conv_58/Reshape_4:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/model_28/graph_update_58/node_set_update_58/simple_conv_58/Reshape_3:0", shape=(None, 320), dtype=float32), dense_shape=Tensor("gradient_tape/model_28/graph_update_58/node_set_update_58/simple_conv_58/Cast_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# Restoring model weights from the end of the best epoch: 368.
# Epoch 378: early stopping
# 1/1 [==============================] - 17s 17s/step
# loss: 0.13953488372093023

# %% [markdown]
# ##### 86% Accuracy is much better than the previously untunned model
